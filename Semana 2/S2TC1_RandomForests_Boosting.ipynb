# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Construcción e implementación de modelos Bagging, Random Forest y XGBoost
#
# En este taller podrán poner en práctica sus conocimientos sobre la construcción e implementación de modelos de Bagging, Random Forest y XGBoost. El taller está constituido por 8 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción precio de automóviles
#
# En este taller se usará el conjunto de datos de Car Listings de Kaggle donde cada observación representa el precio de un automóvil teniendo en cuenta distintas variables como año, marca, modelo, entre otras. El objetivo es predecir el precio del automóvil. Para más detalles puede visitar el siguiente enlace: [datos](https://www.kaggle.com/jpayne/852k-used-car-listings).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación de librerías
# %matplotlib inline
import pandas as pd

# Lectura de la información de archivo .csv
data = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/dataTrain_carListings.zip')

# Preprocesamiento de datos para el taller
data = data.loc[data['Model'].str.contains('Camry')].drop(['Make', 'State'], axis=1)
data = data.join(pd.get_dummies(data['Model'], prefix='M'))
data = data.drop(['Model'], axis=1)

# Visualización dataset
data.head()
# Out:
#      Price  Year  Mileage  M_Camry  M_Camry4dr  M_CamryBase  M_CamryL  \
# 7    21995  2014     6480    False       False        False      True
# 11   13995  2014    39972    False       False        False     False
# 167  17941  2016    18989    False       False        False     False
# 225  12493  2014    51330    False       False        False      True
# 270   7994  2007   116065    False        True        False     False
#
#      M_CamryLE  M_CamrySE  M_CamryXLE
# 7        False      False       False
# 11        True      False       False
# 167      False       True       False
# 225      False      False       False
# 270      False      False       False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10495 entries, 7 to 399976
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        10495 non-null  int64
#  1   Year         10495 non-null  int64
#  2   Mileage      10495 non-null  int64
#  3   M_Camry      10495 non-null  bool
#  4   M_Camry4dr   10495 non-null  bool
#  5   M_CamryBase  10495 non-null  bool
#  6   M_CamryL     10495 non-null  bool
#  7   M_CamryLE    10495 non-null  bool
#  8   M_CamrySE    10495 non-null  bool
#  9   M_CamryXLE   10495 non-null  bool
# dtypes: bool(7), int64(3)
# memory usage: 657.8 KB

# %%
data.describe().T
# Out:
#            count          mean           std     min      25%      50%  \
# Price    10495.0  14538.403716   3922.420961  5002.0  11999.0  15000.0
# Year     10495.0   2013.553883      3.116585  1998.0   2012.0   2014.0
# Mileage  10495.0  52509.430395  36791.736601     5.0  26461.0  41680.0
#
#              75%       max
# Price    16999.0   32444.0
# Year      2016.0    2018.0
# Mileage  71355.5  232658.0

# %%
from ydata_profiling import ProfileReport
carListings_profile = ProfileReport(data, title="Reporte carListings", explorative=True)

# Export  report to  HTML 
carListings_profile.to_file("carListings-data-report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Separación de variables predictoras (X) y variable de interés (y)
y = data['Price']
X = data.drop(['Price'], axis=1)

# %%
# Separación de datos en set de entrenamiento y test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
def encode_bool(X):
    X_encoded = X.copy()
    X_encoded = X_encoded.applymap(lambda x: int(x) if isinstance(x, bool) else x)
    return X_encoded

# %%
X_train_enc = encode_bool(X_train)
X_test_enc = encode_bool(X_test)

# %% [markdown]
# ### Punto 1 - Árbol de decisión manual
#
# En la celda 1 creen un árbol de decisión **manualmente**  que considere los set de entrenamiento y test definidos anteriormente y presenten el RMSE y MAE del modelo en el set de test.

# %%
# Celda 1
# Para este punto se adapta el código del S1LAB1_construccción_calibracion_arboles visto durante la semana 1 para solucionar el problema de regresión
import numpy as np

# Definición funciones impureza
def mse(y):
    if y.shape[0] == 0:
        return 0
    else:
        return ((y - y.mean()) ** 2).mean()
    
def mae(y):
    if y.shape[0] == 0:
        return 0
    return (y - y.median()).abs().mean()

# Definición de la función impurity_reduction para calcular la mejora de una variable predictora j dado el punto de corte k
def impurity_reduction(X_col, y, split, criterio="mse"):
    filter_l = X_col < split
    y_l = y.loc[filter_l]
    y_r = y.loc[~filter_l]
    
    n_l = y_l.shape[0]
    n_r = y_r.shape[0]
    
    if criterio == "mse":
        impurity = mse
    elif criterio == "mae":
        impurity = mae
    else:
        raise ValueError("Criterio invalido, debe ser 'mse' o 'mae'")

    imp_y = impurity(y)
    imp_l = impurity(y_l)
    imp_r = impurity(y_r)
    
    imp_red_ = imp_y - (n_l / (n_l + n_r) * imp_l + n_r / (n_l + n_r) * imp_r)
    return imp_red_

# Definición de la función best_split para calcular cuál es la mejor variable y punto de corte para hacer la bifurcación del árbol
def best_split(X, y, num_pct=10, criterio="mse"):   
    features = range(X.shape[1])
    best_split = [0, 0, -np.inf]  # j, split, gain
    
    # Para todas las variables 
    for j in features:
        splits = np.percentile(X.iloc[:, j], np.arange(0, 100, 100.0 / (num_pct+1)).tolist())
        splits = np.unique(splits)[1:]
        # Para cada partición
        for split in splits:
            gain = impurity_reduction(X.iloc[:, j], y, split, criterio=criterio)        
            if gain > best_split[2]:
                best_split = [j, split, gain] 
    return best_split

# Definición de la función tree_grow para hacer un crecimiento recursivo del árbol
def tree_grow(X, y, level=0, min_gain=0.001, max_depth=None, num_pct=10, criterio="mse" ):
    # Si solo es una observación
    if X.shape[0] == 1:
        tree = dict(y_pred=y.iloc[:1].values[0], level=level, split=-1, n_samples=1, gain=0)
        return tree
    
    # Calcular la mejor división
    j, split, gain = best_split(X, y, num_pct,  criterio=criterio)
    
    # Guardar el árbol y estimar la predicción
    y_pred = y.mean() if criterio == "mse" else y.median()
    tree = dict(y_pred=y_pred, level=level, split=-1, n_samples=X.shape[0], gain=gain)

    # Revisar el criterio de parada 
    if gain < min_gain:
        return tree
    if max_depth is not None:
        if level >= max_depth:
            return tree   
    
    # Continuar creando la partición
    filter_l = X.iloc[:, j] < split
    X_l, y_l = X.loc[filter_l], y.loc[filter_l]
    X_r, y_r = X.loc[~filter_l], y.loc[~filter_l]
    tree['split'] = [j, split]

    # Siguiente iteración para cada partición
    tree['sl'] = tree_grow(X_l, y_l, level + 1, min_gain=min_gain, max_depth=max_depth, num_pct=num_pct)
    tree['sr'] = tree_grow(X_r, y_r, level + 1, min_gain=min_gain, max_depth=max_depth, num_pct=num_pct)
    return tree

# %%
# Aplicación de la función tree_grow usando MSE
mse_tree = tree_grow(X_train_enc, y_train, level=0, min_gain=0.001, max_depth=10, num_pct=10, criterio = "mse")
mse_tree
# Out:
# {'y_pred': 14508.073389276064,
#  'level': 0,
#  'split': [0, 2014.0],
#  'n_samples': 7031,
#  'gain': 8706079.2690802,
#  'sl': {'y_pred': 10234.929955947136,
#   'level': 1,
#   'split': [0, 2012.0],
#   'n_samples': 2270,
#   'gain': 4019659.1499605672,
#   'sl': {'y_pred': 8737.28071379547,
#    'level': 2,
#    'split': [1, 97798.72727272728],
#    'n_samples': 1457,
#    'gain': 1109280.4742891928,
#    'sl': {'y_pred': 9891.465256797583,
#     'level': 3,
#     'split': [0, 2008.0],
#     'n_samples': 662,
#     'gain': 902634.9592679311,
#     'sl': {'y_pred': 8421.194871794873,
#      'level': 4,
#      'split': [0, 2006.0],
#      'n_samples': 195,
#      'gain': 336865.7958247354,
#      'sl': {'y_pred': 7618.9701492537315,
#       'level': 5,
#       'split': [1, 51260.0],
#       'n_samples': 67,
#       'gain': 281288.4641247627,
#       'sl': {'y_pred': 8754.416666666666,
#        'level': 6,
#        'split': [1, 39086.0],
#        'n_samples': 12,
#        'gain': 526056.166865079,
#        'sl': {'y_pred': 9612.6,
#         'level': 7,
#         'split': [2, 0.18181818181818166],
#         'n_samples': 5,
#         'gain': 507387.8400000001,
#         'sl': {'y_pred': 9031.0,
#          'level': 8,
#          'split': [1, 32355.81818181818],
#          'n_samples': 3,
#          'gain': 288800.0,
#          'sl': {'y_pred': 9791,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 8651.0,
#           'level': 9,
#           'split': [1, 36042.27272727273],
#           'n_samples': 2,
#           'gain': 62001.0,
#           'sl': {'y_pred': 8900,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 8402,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 10485.0,
#          'level': 8,
#          'split': [0, 2003.1818181818182],
#          'n_samples': 2,
#          'gain': 255025.0,
#          'sl': {'y_pred': 9980,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 10990,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 8141.428571428572,
#         'level': 7,
#         'split': [0, 2003.090909090909],
#         'n_samples': 7,
#         'gain': 728382.9877551021,
#         'sl': {'y_pred': 6792.0,
#          'level': 8,
#          'split': [1, 39483.27272727273],
#          'n_samples': 2,
#          'gain': 39204.0,
#          'sl': {'y_pred': 6594,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 6990,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 8681.2,
#          'level': 8,
#          'split': [1, 47230.454545454544],
#          'n_samples': 5,
#          'gain': 431517.61,
#          'sl': {'y_pred': 8352.75,
#           'level': 9,
#           'split': [6, 0.09090909090909083],
#           'n_samples': 4,
#           'gain': 153860.0625,
#           'sl': {'y_pred': 7960.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 756.25},
#           'sr': {'y_pred': 8745.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 62500.0}},
#          'sr': {'y_pred': 9995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}},
#       'sr': {'y_pred': 7371.236363636363,
#        'level': 6,
#        'split': [0, 2005.0],
#        'n_samples': 55,
#        'gain': 179453.71601775335,
#        'sl': {'y_pred': 6955.25,
#         'level': 7,
#         'split': [2, 0.5454545454545467],
#         'n_samples': 28,
#         'gain': 220675.44083333318,
#         'sl': {'y_pred': 6792.52,
#          'level': 8,
#          'split': [0, 2004.0],
#          'n_samples': 25,
#          'gain': 111679.65205614048,
#          'sl': {'y_pred': 6980.315789473684,
#           'level': 9,
#           'split': [0, 2000.909090909091],
#           'n_samples': 19,
#           'gain': 218689.628848437,
#           'sl': {'y_pred': 6197.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 123271.20999999998},
#           'sr': {'y_pred': 7259.785714285715,
#            'level': 10,
#            'split': -1,
#            'n_samples': 14,
#            'gain': 141000.96003401373}},
#          'sr': {'y_pred': 6197.833333333333,
#           'level': 9,
#           'split': [1, 70988.18181818182],
#           'n_samples': 6,
#           'gain': 152168.05555555553,
#           'sl': {'y_pred': 6749.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 62250.25},
#           'sr': {'y_pred': 5922.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 1776.333333333333}}},
#         'sr': {'y_pred': 8311.333333333334,
#          'level': 8,
#          'split': [1, 79383.72727272728],
#          'n_samples': 3,
#          'gain': 1421860.0555555555,
#          'sl': {'y_pred': 6625,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 9154.5,
#           'level': 9,
#           'split': [1, 80694.72727272728],
#           'n_samples': 2,
#           'gain': 711492.25,
#           'sl': {'y_pred': 9998,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 8311,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}},
#        'sr': {'y_pred': 7802.62962962963,
#         'level': 7,
#         'split': [1, 74901.54545454544],
#         'n_samples': 27,
#         'gain': 499970.75727023324,
#         'sl': {'y_pred': 8435.066666666668,
#          'level': 8,
#          'split': [1, 73916.0],
#          'n_samples': 15,
#          'gain': 137407.84683760675,
#          'sl': {'y_pred': 8580.461538461539,
#           'level': 9,
#           'split': [1, 71725.81818181818],
#           'n_samples': 13,
#           'gain': 229970.27928994037,
#           'sl': {'y_pred': 8317.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 505579.55047619087},
#           'sr': {'y_pred': 9456.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 1879860.5}},
#          'sr': {'y_pred': 7490.0,
#           'level': 9,
#           'split': [1, 74043.72727272728],
#           'n_samples': 2,
#           'gain': 255025.0,
#           'sl': {'y_pred': 7995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 6985,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 7012.083333333333,
#          'level': 8,
#          'split': [1, 79522.0],
#          'n_samples': 12,
#          'gain': 134220.6824494952,
#          'sl': {'y_pred': 5797,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 7122.545454545455,
#           'level': 9,
#           'split': [1, 96848.63636363637],
#           'n_samples': 11,
#           'gain': 148973.12066115718,
#           'sl': {'y_pred': 7244.6,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 335395.41777777777},
#           'sr': {'y_pred': 5902,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}}},
#      'sr': {'y_pred': 8841.109375,
#       'level': 5,
#       'split': [1, 49103.72727272727],
#       'n_samples': 128,
#       'gain': 574810.8403180004,
#       'sl': {'y_pred': 11198.333333333334,
#        'level': 6,
#        'split': [2, 1.0],
#        'n_samples': 12,
#        'gain': 2491842.0868055564,
#        'sl': {'y_pred': 10082.125,
#         'level': 7,
#         'split': [1, 40533.36363636364],
#         'n_samples': 8,
#         'gain': 462749.92604166653,
#         'sl': {'y_pred': 10960.333333333334,
#          'level': 8,
#          'split': [1, 14535.272727272728],
#          'n_samples': 3,
#          'gain': 600.8888888888887,
#          'sl': {'y_pred': 10995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 10943.0,
#           'level': 9,
#           'split': [1, 39051.72727272727],
#           'n_samples': 2,
#           'gain': 2704.0,
#           'sl': {'y_pred': 10891,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 9555.2,
#          'level': 8,
#          'split': [1, 44816.545454545456],
#          'n_samples': 5,
#          'gain': 518256.0100000001,
#          'sl': {'y_pred': 9195.25,
#           'level': 9,
#           'split': [1, 42056.0],
#           'n_samples': 4,
#           'gain': 477004.6875,
#           'sl': {'y_pred': 9594.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 315218.0},
#           'sr': {'y_pred': 7999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 10995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 13430.75,
#         'level': 7,
#         'split': [1, 39951.545454545456],
#         'n_samples': 4,
#         'gain': 2451573.0625,
#         'sl': {'y_pred': 14996.5,
#          'level': 8,
#          'split': [1, 32342.272727272728],
#          'n_samples': 2,
#          'gain': 2.25,
#          'sl': {'y_pred': 14998,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 14995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 11865.0,
#          'level': 8,
#          'split': [0, 2006.090909090909],
#          'n_samples': 2,
#          'gain': 1243225.0,
#          'sl': {'y_pred': 10750,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 12980,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}},
#       'sr': {'y_pred': 8597.258620689656,
#        'level': 6,
#        'split': [1, 77212.90909090909],
#        'n_samples': 116,
#        'gain': 300725.74571241834,
#        'sl': {'y_pred': 9325.166666666666,
#         'level': 7,
#         'split': [2, 0.8181818181818201],
#         'n_samples': 42,
#         'gain': 223701.87777777785,
#         'sl': {'y_pred': 9026.033333333333,
#          'level': 8,
#          'split': [1, 68898.36363636363],
#          'n_samples': 30,
#          'gain': 163876.53397660796,
#          'sl': {'y_pred': 9334.052631578947,
#           'level': 9,
#           'split': [3, 0.27272727272727293],
#           'n_samples': 19,
#           'gain': 353862.06389658386,
#           'sl': {'y_pred': 10486.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 262656.25},
#           'sr': {'y_pred': 9026.866666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 15,
#            'gain': 349579.38962962944}},
#          'sr': {'y_pred': 8494.0,
#           'level': 9,
#           'split': [1, 74246.90909090909],
#           'n_samples': 11,
#           'gain': 499666.72222222236,
#           'sl': {'y_pred': 8160.777777777777,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 85951.186728395},
#           'sr': {'y_pred': 9993.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 30.25}}},
#         'sr': {'y_pred': 10073.0,
#          'level': 8,
#          'split': [1, 53000.0],
#          'n_samples': 12,
#          'gain': 1099680.3636363638,
#          'sl': {'y_pred': 6595,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 10389.181818181818,
#           'level': 9,
#           'split': [1, 72117.27272727274],
#           'n_samples': 11,
#           'gain': 561955.0995179064,
#           'sl': {'y_pred': 9930.125,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'gain': 289929.796875},
#           'sr': {'y_pred': 11613.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 1309501.388888889}}}},
#        'sr': {'y_pred': 8184.121621621622,
#         'level': 7,
#         'split': [1, 83676.45454545454],
#         'n_samples': 74,
#         'gain': 59164.002275248524,
#         'sl': {'y_pred': 8583.8,
#          'level': 8,
#          'split': [1, 83169.36363636363],
#          'n_samples': 20,
#          'gain': 242901.12249999982,
#          'sl': {'y_pred': 8337.375,
#           'level': 9,
#           'split': [1, 80181.45454545454],
#           'n_samples': 16,
#           'gain': 403140.00223214296,
#           'sl': {'y_pred': 8897.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 843484.013888889},
#           'sr': {'y_pred': 7617.428571428572,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 247022.0544217687}},
#          'sr': {'y_pred': 9569.5,
#           'level': 9,
#           'split': [0, 2006.090909090909],
#           'n_samples': 4,
#           'gain': 141000.25,
#           'sl': {'y_pred': 9945.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 2025.0},
#           'sr': {'y_pred': 9194.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 41616.0}}},
#         'sr': {'y_pred': 8036.092592592592,
#          'level': 8,
#          'split': [2, 0.5454545454545467],
#          'n_samples': 54,
#          'gain': 73997.193420914,
#          'sl': {'y_pred': 8204.794871794871,
#           'level': 9,
#           'split': [1, 95481.81818181819],
#           'n_samples': 39,
#           'gain': 97051.35718981875,
#           'sl': {'y_pred': 8350.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 32,
#            'gain': 158721.641025641},
#           'sr': {'y_pred': 7538.714285714285,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 395633.41836734704}},
#          'sr': {'y_pred': 7597.466666666666,
#           'level': 9,
#           'split': [1, 85270.54545454546],
#           'n_samples': 15,
#           'gain': 272375.47313131334,
#           'sl': {'y_pred': 6732.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 181056.33333333337},
#           'sr': {'y_pred': 7912.181818181818,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 199708.2851239671}}}}}}},
#     'sr': {'y_pred': 10505.389721627409,
#      'level': 4,
#      'split': [1, 64289.72727272727],
#      'n_samples': 467,
#      'gain': 504235.0878509972,
#      'sl': {'y_pred': 11661.0,
#       'level': 5,
#       'split': [2, 1.0],
#       'n_samples': 128,
#       'gain': 127187.17020089272,
#       'sl': {'y_pred': 11526.205357142857,
#        'level': 6,
#        'split': [0, 2009.1818181818182],
#        'n_samples': 112,
#        'gain': 464241.151607879,
#        'sl': {'y_pred': 10107.857142857143,
#         'level': 7,
#         'split': [1, 53685.36363636363],
#         'n_samples': 21,
#         'gain': 198088.69387755124,
#         'sl': {'y_pred': 10457.0,
#          'level': 8,
#          'split': [0, 2008.1818181818182],
#          'n_samples': 13,
#          'gain': 82477.63333333307,
#          'sl': {'y_pred': 9932.666666666666,
#           'level': 9,
#           'split': [1, 28379.090909090908],
#           'n_samples': 3,
#           'gain': 172088.88888888888,
#           'sl': {'y_pred': 9346,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10226.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 75076.0}},
#          'sr': {'y_pred': 10614.3,
#           'level': 9,
#           'split': [1, 52637.72727272727],
#           'n_samples': 10,
#           'gain': 631866.0100000005,
#           'sl': {'y_pred': 10349.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 749904.2222222222},
#           'sr': {'y_pred': 12999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 9540.5,
#          'level': 8,
#          'split': [0, 2008.6363636363637],
#          'n_samples': 8,
#          'gain': 434256.03571428545,
#          'sl': {'y_pred': 7797,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 9789.57142857143,
#           'level': 9,
#           'split': [1, 60447.545454545456],
#           'n_samples': 7,
#           'gain': 563890.6139455786,
#           'sl': {'y_pred': 9139.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 900090.1875},
#           'sr': {'y_pred': 10656.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 228938.88888888888}}}},
#        'sr': {'y_pred': 11853.516483516483,
#         'level': 7,
#         'split': [1, 51648.0],
#         'n_samples': 91,
#         'gain': 50849.02912255749,
#         'sl': {'y_pred': 12102.536585365853,
#          'level': 8,
#          'split': [0, 2011.0],
#          'n_samples': 41,
#          'gain': 494212.3453570267,
#          'sl': {'y_pred': 13340.3,
#           'level': 9,
#           'split': [6, 0.3636363636363642],
#           'n_samples': 10,
#           'gain': 528383.6099999999,
#           'sl': {'y_pred': 13703.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'gain': 278324.7041666666},
#           'sr': {'y_pred': 11886.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 149382.25}},
#          'sr': {'y_pred': 11703.258064516129,
#           'level': 9,
#           'split': [8, 0.2727272727272734],
#           'n_samples': 31,
#           'gain': 390489.46950101596,
#           'sl': {'y_pred': 11498.714285714286,
#            'level': 10,
#            'split': -1,
#            'n_samples': 28,
#            'gain': 456638.5905895692},
#           'sr': {'y_pred': 13612.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 1567040.0555555555}}},
#         'sr': {'y_pred': 11649.32,
#          'level': 8,
#          'split': [1, 53171.90909090909],
#          'n_samples': 50,
#          'gain': 46179.14471111074,
#          'sl': {'y_pred': 12294.0,
#           'level': 9,
#           'split': [1, 52819.545454545456],
#           'n_samples': 5,
#           'gain': 1476225.0,
#           'sl': {'y_pred': 12901.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 209880.75},
#           'sr': {'y_pred': 9864,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 11577.68888888889,
#           'level': 9,
#           'split': [1, 55582.0],
#           'n_samples': 45,
#           'gain': 255230.1033453783,
#           'sl': {'y_pred': 9960.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 307360.0208333334},
#           'sr': {'y_pred': 11735.487804878048,
#            'level': 10,
#            'split': -1,
#            'n_samples': 41,
#            'gain': 42332.79187501012}}}}},
#       'sr': {'y_pred': 12604.5625,
#        'level': 6,
#        'split': [1, 29012.18181818182],
#        'n_samples': 16,
#        'gain': 2757470.438058036,
#        'sl': {'y_pred': 16998.0,
#         'level': 7,
#         'split': [1, 17229.272727272728],
#         'n_samples': 2,
#         'gain': 1000000.0,
#         'sl': {'y_pred': 15998,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 17998,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 11976.92857142857,
#         'level': 7,
#         'split': [1, 48220.818181818184],
#         'n_samples': 14,
#         'gain': 313608.12346938765,
#         'sl': {'y_pred': 11225.6,
#          'level': 8,
#          'split': [1, 44121.181818181816],
#          'n_samples': 5,
#          'gain': 1403751.04,
#          'sl': {'y_pred': 11818.0,
#           'level': 9,
#           'split': [1, 42631.0],
#           'n_samples': 4,
#           'gain': 225776.33333333334,
#           'sl': {'y_pred': 12092.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 21562.72222222222},
#           'sr': {'y_pred': 10995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 8856,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 12394.333333333334,
#          'level': 8,
#          'split': [0, 2008.6363636363637],
#          'n_samples': 9,
#          'gain': 760760.0222222223,
#          'sl': {'y_pred': 13369.5,
#           'level': 9,
#           'split': [1, 56659.72727272727],
#           'n_samples': 4,
#           'gain': 770884.0,
#           'sl': {'y_pred': 14247.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 5073756.25},
#           'sr': {'y_pred': 12491.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 253512.25}},
#          'sr': {'y_pred': 11614.2,
#           'level': 9,
#           'split': [0, 2010.2727272727273],
#           'n_samples': 5,
#           'gain': 1411106.4099999997,
#           'sl': {'y_pred': 11020.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 196480.02083333337},
#           'sr': {'y_pred': 13990,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}}},
#      'sr': {'y_pred': 10069.053097345133,
#       'level': 5,
#       'split': [0, 2010.0],
#       'n_samples': 339,
#       'gain': 192796.23313530372,
#       'sl': {'y_pred': 9439.756756756757,
#        'level': 6,
#        'split': [1, 91364.0],
#        'n_samples': 111,
#        'gain': 119713.49824728188,
#        'sl': {'y_pred': 9606.888888888889,
#         'level': 7,
#         'split': [2, 1.0],
#         'n_samples': 90,
#         'gain': 41075.65582248918,
#         'sl': {'y_pred': 9512.648648648648,
#          'level': 8,
#          'split': [0, 2009.0],
#          'n_samples': 74,
#          'gain': 44930.666989565594,
#          'sl': {'y_pred': 9175.904761904761,
#           'level': 9,
#           'split': [1, 87070.72727272728],
#           'n_samples': 21,
#           'gain': 49378.37188208604,
#           'sl': {'y_pred': 9248.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 19,
#            'gain': 57811.88235294109},
#           'sr': {'y_pred': 8491.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 246016.0}},
#          'sr': {'y_pred': 9646.075471698114,
#           'level': 9,
#           'split': [1, 74730.54545454546],
#           'n_samples': 53,
#           'gain': 81078.24511501286,
#           'sl': {'y_pred': 9192.866666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 15,
#            'gain': 81746.33373737376},
#           'sr': {'y_pred': 9824.973684210527,
#            'level': 10,
#            'split': -1,
#            'n_samples': 38,
#            'gain': 149575.61257451726}}},
#         'sr': {'y_pred': 10042.75,
#          'level': 8,
#          'split': [1, 79473.54545454546],
#          'n_samples': 16,
#          'gain': 379612.60416666674,
#          'sl': {'y_pred': 10838.166666666666,
#           'level': 9,
#           'split': [1, 77107.18181818182],
#           'n_samples': 6,
#           'gain': 926938.2722222223,
#           'sl': {'y_pred': 10407.6,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 1455159.6899999997},
#           'sr': {'y_pred': 12991,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 9565.5,
#           'level': 9,
#           'split': [1, 88990.90909090909],
#           'n_samples': 10,
#           'gain': 647858.6785714284,
#           'sl': {'y_pred': 9038.57142857143,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 587993.2163265309},
#           'sr': {'y_pred': 10795.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 845000.0}}}},
#        'sr': {'y_pred': 8723.47619047619,
#         'level': 7,
#         'split': [1, 92295.45454545454],
#         'n_samples': 21,
#         'gain': 496370.0689819788,
#         'sl': {'y_pred': 10895.0,
#          'level': 8,
#          'split': [1, 91406.72727272728],
#          'n_samples': 2,
#          'gain': 40000.0,
#          'sl': {'y_pred': 11095,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 10695,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 8494.894736842105,
#          'level': 8,
#          'split': [3, 0.8181818181818166],
#          'n_samples': 19,
#          'gain': 192381.76669744565,
#          'sl': {'y_pred': 8911.0,
#           'level': 9,
#           'split': [1, 97337.72727272728],
#           'n_samples': 10,
#           'gain': 861184.0,
#           'sl': {'y_pred': 8601.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 349917.46031746035},
#           'sr': {'y_pred': 11695,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 8032.555555555556,
#           'level': 9,
#           'split': [1, 96728.54545454546],
#           'n_samples': 9,
#           'gain': 176089.20723104046,
#           'sl': {'y_pred': 8256.857142857143,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 503523.431972789},
#           'sr': {'y_pred': 7247.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 63756.25}}}}},
#       'sr': {'y_pred': 10375.421052631578,
#        'level': 6,
#        'split': [1, 91629.45454545454],
#        'n_samples': 228,
#        'gain': 222411.42716985382,
#        'sl': {'y_pred': 10663.638554216868,
#         'level': 7,
#         'split': [6, 1.0],
#         'n_samples': 166,
#         'gain': 34564.22497119731,
#         'sl': {'y_pred': 10749.175182481751,
#          'level': 8,
#          'split': [1, 74625.18181818182],
#          'n_samples': 137,
#          'gain': 5590.146339372499,
#          'sl': {'y_pred': 10847.8,
#           'level': 9,
#           'split': [1, 70779.45454545454],
#           'n_samples': 50,
#           'gain': 38657.13391304342,
#           'sl': {'y_pred': 10666.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 27,
#            'gain': 16958.680555555853},
#           'sr': {'y_pred': 11060.826086956522,
#            'level': 10,
#            'split': -1,
#            'n_samples': 23,
#            'gain': 191450.5536051856}},
#          'sr': {'y_pred': 10692.494252873563,
#           'level': 9,
#           'split': [1, 78631.0],
#           'n_samples': 87,
#           'gain': 29821.013627798297,
#           'sl': {'y_pred': 10412.708333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 24,
#            'gain': 176555.56800073083},
#           'sr': {'y_pred': 10799.079365079366,
#            'level': 10,
#            'split': -1,
#            'n_samples': 63,
#            'gain': 60046.44009085093}}},
#         'sr': {'y_pred': 10259.551724137931,
#          'level': 8,
#          'split': [0, 2011.0],
#          'n_samples': 29,
#          'gain': 351676.640756469,
#          'sl': {'y_pred': 9645.714285714286,
#           'level': 9,
#           'split': [1, 84089.72727272728],
#           'n_samples': 14,
#           'gain': 114465.6548752833,
#           'sl': {'y_pred': 9897.888888888889,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 38417.48209876544},
#           'sr': {'y_pred': 9191.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 325547.6266666667}},
#          'sr': {'y_pred': 10832.466666666667,
#           'level': 9,
#           'split': [1, 76400.72727272728],
#           'n_samples': 15,
#           'gain': 308428.9458585859,
#           'sl': {'y_pred': 9911.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 197376.75},
#           'sr': {'y_pred': 11167.363636363636,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 453700.28696051426}}}},
#        'sr': {'y_pred': 9603.741935483871,
#         'level': 7,
#         'split': [1, 96234.18181818182],
#         'n_samples': 62,
#         'gain': 145138.87654651818,
#         'sl': {'y_pred': 9896.307692307691,
#          'level': 8,
#          'split': [0, 2011.0],
#          'n_samples': 39,
#          'gain': 163856.10650887573,
#          'sl': {'y_pred': 9323.846153846154,
#           'level': 9,
#           'split': [3, 0.09090909090909083],
#           'n_samples': 13,
#           'gain': 157033.504303389,
#           'sl': {'y_pred': 8394.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 159600.25},
#           'sr': {'y_pred': 9492.818181818182,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 66180.83707201865}},
#          'sr': {'y_pred': 10182.538461538461,
#           'level': 9,
#           'split': [1, 92118.63636363637],
#           'n_samples': 26,
#           'gain': 58109.3354772313,
#           'sl': {'y_pred': 10850.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 148512.5},
#           'sr': {'y_pred': 10095.478260869566,
#            'level': 10,
#            'split': -1,
#            'n_samples': 23,
#            'gain': 161247.25786074367}}},
#         'sr': {'y_pred': 9107.652173913044,
#          'level': 8,
#          'split': [6, 1.0],
#          'n_samples': 23,
#          'gain': 85951.03971607541,
#          'sl': {'y_pred': 9281.823529411764,
#           'level': 9,
#           'split': [1, 97007.36363636363],
#           'n_samples': 17,
#           'gain': 107694.99470483384,
#           'sl': {'y_pred': 9039.454545454546,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 446168.92975206603},
#           'sr': {'y_pred': 9726.166666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 132526.6805555556}},
#          'sr': {'y_pred': 8614.166666666666,
#           'level': 9,
#           'split': [0, 2010.3636363636363],
#           'n_samples': 6,
#           'gain': 72517.01388888893,
#           'sl': {'y_pred': 8995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 0.0},
#           'sr': {'y_pred': 8423.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 109538.52083333334}}}}}}}},
#    'sr': {'y_pred': 7776.186163522013,
#     'level': 3,
#     'split': [0, 2010.0],
#     'n_samples': 795,
#     'gain': 619143.7020776966,
#     'sl': {'y_pred': 7272.613475177305,
#      'level': 4,
#      'split': [1, 123765.27272727274],
#      'n_samples': 564,
#      'gain': 218601.14820177807,
#      'sl': {'y_pred': 7785.453125,
#       'level': 5,
#       'split': [0, 2006.0],
#       'n_samples': 256,
#       'gain': 243500.67791905068,
#       'sl': {'y_pred': 6702.295454545455,
#        'level': 6,
#        'split': [1, 99547.90909090909],
#        'n_samples': 44,
#        'gain': 83120.51782024815,
#        'sl': {'y_pred': 7614.0,
#         'level': 7,
#         'split': [1, 98674.18181818182],
#         'n_samples': 4,
#         'gain': 1264500.25,
#         'sl': {'y_pred': 8738.5,
#          'level': 8,
#          'split': [1, 98604.0],
#          'n_samples': 2,
#          'gain': 552792.25,
#          'sl': {'y_pred': 9482,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 7995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 6489.5,
#          'level': 8,
#          'split': [0, 2004.090909090909],
#          'n_samples': 2,
#          'gain': 255530.25,
#          'sl': {'y_pred': 5984,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 6995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 6611.125,
#         'level': 7,
#         'split': [0, 2002.0],
#         'n_samples': 40,
#         'gain': 38467.61838400923,
#         'sl': {'y_pred': 5922.333333333333,
#          'level': 8,
#          'split': [1, 101194.54545454546],
#          'n_samples': 3,
#          'gain': 10853.555555555558,
#          'sl': {'y_pred': 5775,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 5996.0,
#           'level': 9,
#           'split': [0, 1998.2727272727273],
#           'n_samples': 2,
#           'gain': 16.0,
#           'sl': {'y_pred': 5992,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 6000,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 6666.972972972973,
#          'level': 8,
#          'split': [0, 2003.5454545454545],
#          'n_samples': 37,
#          'gain': 28868.455254095607,
#          'sl': {'y_pred': 7018.714285714285,
#           'level': 9,
#           'split': [0, 2002.3636363636363],
#           'n_samples': 7,
#           'gain': 814286.9897959185,
#           'sl': {'y_pred': 6448.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 343982.25},
#           'sr': {'y_pred': 8445.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 215760.25}},
#          'sr': {'y_pred': 6584.9,
#           'level': 9,
#           'split': [0, 2005.0],
#           'n_samples': 30,
#           'gain': 79042.31751322746,
#           'sl': {'y_pred': 6155.444444444444,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 123683.11199294531},
#           'sr': {'y_pred': 6768.952380952381,
#            'level': 10,
#            'split': -1,
#            'n_samples': 21,
#            'gain': 84597.23193156067}}}}},
#       'sr': {'y_pred': 8010.259433962264,
#        'level': 6,
#        'split': [0, 2008.0],
#        'n_samples': 212,
#        'gain': 83976.4738763757,
#        'sl': {'y_pred': 7731.209090909091,
#         'level': 7,
#         'split': [1, 102810.81818181818],
#         'n_samples': 110,
#         'gain': 24566.712139577605,
#         'sl': {'y_pred': 8063.7,
#          'level': 8,
#          'split': [1, 97982.81818181818],
#          'n_samples': 20,
#          'gain': 367720.95999999973,
#          'sl': {'y_pred': 6244.5,
#           'level': 9,
#           'split': [0, 2006.090909090909],
#           'n_samples': 2,
#           'gain': 555770.25,
#           'sl': {'y_pred': 6990,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 5499,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 8265.833333333334,
#           'level': 9,
#           'split': [6, 1.0],
#           'n_samples': 18,
#           'gain': 241633.47222222178,
#           'sl': {'y_pred': 8485.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 15,
#            'gain': 363283.7606837605},
#           'sr': {'y_pred': 7166.666666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 347222.22222222225}}},
#         'sr': {'y_pred': 7657.322222222222,
#          'level': 8,
#          'split': [0, 2007.0],
#          'n_samples': 90,
#          'gain': 59710.371491908794,
#          'sl': {'y_pred': 7131.8125,
#           'level': 9,
#           'split': [1, 117988.0],
#           'n_samples': 16,
#           'gain': 133469.87526041665,
#           'sl': {'y_pred': 7414.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 437449.9600000001},
#           'sr': {'y_pred': 6660.166666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 519860.0555555555}},
#          'sr': {'y_pred': 7770.945945945946,
#           'level': 9,
#           'split': [1, 117960.36363636363],
#           'n_samples': 74,
#           'gain': 36100.44045010256,
#           'sl': {'y_pred': 7679.166666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 60,
#            'gain': 33260.11868125084},
#           'sr': {'y_pred': 8164.285714285715,
#            'level': 10,
#            'split': -1,
#            'n_samples': 14,
#            'gain': 596344.3469387756}}}},
#        'sr': {'y_pred': 8311.196078431372,
#         'level': 7,
#         'split': [2, 1.0],
#         'n_samples': 102,
#         'gain': 48140.3246973434,
#         'sl': {'y_pred': 8216.558139534884,
#          'level': 8,
#          'split': [0, 2008.909090909091],
#          'n_samples': 86,
#          'gain': 50056.43979990785,
#          'sl': {'y_pred': 7918.548387096775,
#           'level': 9,
#           'split': [3, 0.18181818181818166],
#           'n_samples': 31,
#           'gain': 89853.43306110031,
#           'sl': {'y_pred': 7449.888888888889,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 71421.00154320989},
#           'sr': {'y_pred': 8110.272727272727,
#            'level': 10,
#            'split': -1,
#            'n_samples': 22,
#            'gain': 104722.4546602387}},
#          'sr': {'y_pred': 8384.527272727273,
#           'level': 9,
#           'split': [6, 0.18181818181818699],
#           'n_samples': 55,
#           'gain': 55806.34299357212,
#           'sl': {'y_pred': 8495.888888888889,
#            'level': 10,
#            'split': -1,
#            'n_samples': 45,
#            'gain': 68014.09426092729},
#           'sr': {'y_pred': 7883.4,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 282186.9066666666}}},
#         'sr': {'y_pred': 8819.875,
#          'level': 8,
#          'split': [1, 103726.81818181818],
#          'n_samples': 16,
#          'gain': 577459.4389204546,
#          'sl': {'y_pred': 9947.0,
#           'level': 9,
#           'split': [1, 99291.18181818182],
#           'n_samples': 5,
#           'gain': 527076.0,
#           'sl': {'y_pred': 8495,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10310.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 1062075.0}},
#          'sr': {'y_pred': 8307.545454545454,
#           'level': 9,
#           'split': [1, 118645.45454545454],
#           'n_samples': 11,
#           'gain': 168604.48530762165,
#           'sl': {'y_pred': 8501.111111111111,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 319146.07654320984},
#           'sr': {'y_pred': 7436.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 199362.25}}}}}},
#      'sr': {'y_pred': 6846.357142857143,
#       'level': 5,
#       'split': [0, 2007.0],
#       'n_samples': 308,
#       'gain': 123621.95083369454,
#       'sl': {'y_pred': 6323.864583333333,
#        'level': 6,
#        'split': [1, 161690.36363636365],
#        'n_samples': 96,
#        'gain': 45271.045143005555,
#        'sl': {'y_pred': 6485.0327868852455,
#         'level': 7,
#         'split': [1, 148335.36363636365],
#         'n_samples': 61,
#         'gain': 286488.6445584032,
#         'sl': {'y_pred': 6233.98,
#          'level': 8,
#          'split': [0, 2004.0],
#          'n_samples': 50,
#          'gain': 28844.512741025712,
#          'sl': {'y_pred': 6057.208333333333,
#           'level': 9,
#           'split': [0, 2002.0],
#           'n_samples': 24,
#           'gain': 37587.50188707729,
#           'sl': {'y_pred': 6987,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 6016.782608695652,
#            'level': 10,
#            'split': -1,
#            'n_samples': 23,
#            'gain': 30985.352938649303}},
#          'sr': {'y_pred': 6397.153846153846,
#           'level': 9,
#           'split': [1, 131323.9090909091],
#           'n_samples': 26,
#           'gain': 15514.509023668594,
#           'sl': {'y_pred': 6239.6,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 265705.88444444444},
#           'sr': {'y_pred': 6495.625,
#            'level': 10,
#            'split': -1,
#            'n_samples': 16,
#            'gain': 62708.78000992065}}},
#         'sr': {'y_pred': 7626.181818181818,
#          'level': 8,
#          'split': [0, 2004.4545454545455],
#          'n_samples': 11,
#          'gain': 759584.1487603302,
#          'sl': {'y_pred': 9475.0,
#           'level': 9,
#           'split': [1, 148653.18181818182],
#           'n_samples': 2,
#           'gain': 275625.0,
#           'sl': {'y_pred': 10000,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 8950,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 7215.333333333333,
#           'level': 9,
#           'split': [7, 0.5454545454545459],
#           'n_samples': 9,
#           'gain': 672476.3888888891,
#           'sl': {'y_pred': 6777.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 192099.60000000003},
#           'sr': {'y_pred': 8749.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 1563750.25}}}},
#        'sr': {'y_pred': 6042.971428571429,
#         'level': 7,
#         'split': [1, 195653.8181818182],
#         'n_samples': 35,
#         'gain': 85648.20326530619,
#         'sl': {'y_pred': 5896.642857142857,
#          'level': 8,
#          'split': [0, 2004.0],
#          'n_samples': 28,
#          'gain': 71302.08333333337,
#          'sl': {'y_pred': 6359.142857142857,
#           'level': 9,
#           'split': [1, 166358.27272727274],
#           'n_samples': 7,
#           'gain': 137291.43673469388,
#           'sl': {'y_pred': 6945.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 2500.0},
#           'sr': {'y_pred': 6124.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 97718.76}},
#          'sr': {'y_pred': 5742.476190476191,
#           'level': 9,
#           'split': [1, 171152.0909090909],
#           'n_samples': 21,
#           'gain': 96332.50051535765,
#           'sl': {'y_pred': 5446.545454545455,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 25346.647933884302},
#           'sr': {'y_pred': 6068.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 247977.33333333334}}},
#         'sr': {'y_pred': 6628.285714285715,
#          'level': 8,
#          'split': [1, 214001.0],
#          'n_samples': 7,
#          'gain': 543622.532653061,
#          'sl': {'y_pred': 7094.6,
#           'level': 9,
#           'split': [1, 206851.18181818182],
#           'n_samples': 5,
#           'gain': 2108884.84,
#           'sl': {'y_pred': 6368.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 256668.75},
#           'sr': {'y_pred': 9999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 5462.5,
#           'level': 9,
#           'split': [0, 2002.1818181818182],
#           'n_samples': 2,
#           'gain': 166056.25,
#           'sl': {'y_pred': 5055,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 5870,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}},
#       'sr': {'y_pred': 7082.957547169812,
#        'level': 6,
#        'split': [1, 138743.72727272726],
#        'n_samples': 212,
#        'gain': 186012.93452698342,
#        'sl': {'y_pred': 7557.052083333333,
#         'level': 7,
#         'split': [6, 1.0],
#         'n_samples': 96,
#         'gain': 83341.94607204897,
#         'sl': {'y_pred': 7666.166666666667,
#          'level': 8,
#          'split': [1, 127203.18181818181],
#          'n_samples': 84,
#          'gain': 27983.369466222823,
#          'sl': {'y_pred': 7393.739130434783,
#           'level': 9,
#           'split': [1, 123861.0],
#           'n_samples': 23,
#           'gain': 199200.72594292928,
#           'sl': {'y_pred': 5947.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 2256.25},
#           'sr': {'y_pred': 7531.476190476191,
#            'level': 10,
#            'split': -1,
#            'n_samples': 21,
#            'gain': 61562.70498866204}},
#          'sr': {'y_pred': 7768.88524590164,
#           'level': 9,
#           'split': [1, 136209.36363636365],
#           'n_samples': 61,
#           'gain': 15031.151391854743,
#           'sl': {'y_pred': 7711.38,
#            'level': 10,
#            'split': -1,
#            'n_samples': 50,
#            'gain': 55143.5633777777},
#           'sr': {'y_pred': 8030.272727272727,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 323780.74077135}}},
#         'sr': {'y_pred': 6793.25,
#          'level': 8,
#          'split': [0, 2009.0],
#          'n_samples': 12,
#          'gain': 173289.6446428572,
#          'sl': {'y_pred': 6441.428571428572,
#           'level': 9,
#           'split': [0, 2007.3636363636363],
#           'n_samples': 7,
#           'gain': 98775.20204081625,
#           'sl': {'y_pred': 6640.2,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 333390.76000000007},
#           'sr': {'y_pred': 5944.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 1980.25}},
#          'sr': {'y_pred': 7285.8,
#           'level': 9,
#           'split': [1, 137619.18181818182],
#           'n_samples': 5,
#           'gain': 268220.4099999999,
#           'sl': {'y_pred': 7544.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 67575.02083333333},
#           'sr': {'y_pred': 6250,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}},
#        'sr': {'y_pred': 6690.603448275862,
#         'level': 7,
#         'split': [1, 146894.9090909091],
#         'n_samples': 116,
#         'gain': 51789.09136126214,
#         'sl': {'y_pred': 7059.3125,
#          'level': 8,
#          'split': [0, 2009.0],
#          'n_samples': 32,
#          'gain': 130130.22005208326,
#          'sl': {'y_pred': 6851.041666666667,
#           'level': 9,
#           'split': [1, 146144.0],
#           'n_samples': 24,
#           'gain': 58582.87723214307,
#           'sl': {'y_pred': 6942.523809523809,
#            'level': 10,
#            'split': -1,
#            'n_samples': 21,
#            'gain': 116047.36848072556},
#           'sr': {'y_pred': 6210.666666666667,
# ...
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 16942.666666666668,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 307327.9999999998}},
#          'sr': {'y_pred': 19301.333333333332,
#           'level': 9,
#           'split': [1, 42081.09090909091],
#           'n_samples': 3,
#           'gain': 1441036.0555555557,
#           'sl': {'y_pred': 20999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 18452.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 209306.25}}},
#         'sr': {'y_pred': 16596.2,
#          'level': 8,
#          'split': [1, 45647.90909090909],
#          'n_samples': 5,
#          'gain': 541561.1266666669,
#          'sl': {'y_pred': 17497.5,
#           'level': 9,
#           'split': [1, 45412.454545454544],
#           'n_samples': 2,
#           'gain': 2257506.25,
#           'sl': {'y_pred': 15995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 19000,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 15995.333333333334,
#           'level': 9,
#           'split': [1, 46836.454545454544],
#           'n_samples': 3,
#           'gain': 2016701.3888888885,
#           'sl': {'y_pred': 13987,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 16999.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 0.25}}}}}}}},
#    'sr': {'y_pred': 21800.491525423728,
#     'level': 3,
#     'split': [1, 10269.90909090909],
#     'n_samples': 118,
#     'gain': 877457.3612354994,
#     'sl': {'y_pred': 23037.60465116279,
#      'level': 4,
#      'split': [1, 1049.090909090909],
#      'n_samples': 43,
#      'gain': 1130942.1059235083,
#      'sl': {'y_pred': 26358.25,
#       'level': 5,
#       'split': [0, 2017.1818181818182],
#       'n_samples': 4,
#       'gain': 12345451.020833332,
#       'sl': {'y_pred': 24329.666666666668,
#        'level': 6,
#        'split': [1, 461.5454545454545],
#        'n_samples': 3,
#        'gain': 4003506.7222222225,
#        'sl': {'y_pred': 25744.5,
#         'level': 7,
#         'split': [1, 349.54545454545456],
#         'n_samples': 2,
#         'gain': 3046770.25,
#         'sl': {'y_pred': 23999,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 27490,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 21500,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0}},
#       'sr': {'y_pred': 32444,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'gain': 0}},
#      'sr': {'y_pred': 22697.02564102564,
#       'level': 5,
#       'split': [1, 3697.3636363636365],
#       'n_samples': 39,
#       'gain': 257538.50641879486,
#       'sl': {'y_pred': 21887.363636363636,
#        'level': 6,
#        'split': [1, 1853.1818181818182],
#        'n_samples': 11,
#        'gain': 1284415.923324151,
#        'sl': {'y_pred': 24291.5,
#         'level': 7,
#         'split': [1, 1114.4545454545455],
#         'n_samples': 2,
#         'gain': 2206710.25,
#         'sl': {'y_pred': 22806,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 25777,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 21353.11111111111,
#         'level': 7,
#         'split': [1, 3042.6363636363635],
#         'n_samples': 9,
#         'gain': 324459.8765432099,
#         'sl': {'y_pred': 20950.333333333332,
#          'level': 8,
#          'split': [1, 2676.3636363636365],
#          'n_samples': 6,
#          'gain': 763102.2222222222,
#          'sl': {'y_pred': 21341.0,
#           'level': 9,
#           'split': [1, 2631.181818181818],
#           'n_samples': 5,
#           'gain': 104652.25,
#           'sl': {'y_pred': 21179.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 467482.6875},
#           'sr': {'y_pred': 21988,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 18997,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 22158.666666666668,
#          'level': 8,
#          'split': [1, 3629.181818181818],
#          'n_samples': 3,
#          'gain': 957266.7222222221,
#          'sl': {'y_pred': 22850.5,
#           'level': 9,
#           'split': [1, 3574.3636363636365],
#           'n_samples': 2,
#           'gain': 1640.25,
#           'sl': {'y_pred': 22891,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 22810,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 20775,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}},
#       'sr': {'y_pred': 23015.10714285714,
#        'level': 6,
#        'split': [1, 3932.4545454545455],
#        'n_samples': 28,
#        'gain': 388465.7861394556,
#        'sl': {'y_pred': 24814.333333333332,
#         'level': 7,
#         'split': [1, 3805.818181818182],
#         'n_samples': 3,
#         'gain': 1654986.8888888895,
#         'sl': {'y_pred': 22995,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 25724.0,
#          'level': 8,
#          'split': [1, 3856.5454545454545],
#          'n_samples': 2,
#          'gain': 3147076.0,
#          'sl': {'y_pred': 27498,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 23950,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 22799.2,
#         'level': 7,
#         'split': [1, 7236.545454545455],
#         'n_samples': 25,
#         'gain': 135558.966944444,
#         'sl': {'y_pred': 22523.0625,
#          'level': 8,
#          'split': [1, 6292.0],
#          'n_samples': 16,
#          'gain': 1011239.381510417,
#          'sl': {'y_pred': 23302.0,
#           'level': 9,
#           'split': [1, 6061.0],
#           'n_samples': 10,
#           'gain': 636272.1111111112,
#           'sl': {'y_pred': 23036.11111111111,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 194133.72839506168},
#           'sr': {'y_pred': 25695,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 21224.833333333332,
#           'level': 9,
#           'split': [1, 7072.727272727273],
#           'n_samples': 6,
#           'gain': 2454435.3388888882,
#           'sl': {'y_pred': 20524.2,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 1510418.0266666673},
#           'sr': {'y_pred': 24728,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 23290.11111111111,
#          'level': 8,
#          'split': [1, 9241.272727272728],
#          'n_samples': 9,
#          'gain': 124310.51940035261,
#          'sl': {'y_pred': 23478.571428571428,
#           'level': 9,
#           'split': [1, 8669.636363636364],
#           'n_samples': 7,
#           'gain': 1058760.030612245,
#           'sl': {'y_pred': 23058.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 78306.69444444444},
#           'sr': {'y_pred': 25999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 22630.5,
#           'level': 9,
#           'split': [1, 9567.0],
#           'n_samples': 2,
#           'gain': 21462.25,
#           'sl': {'y_pred': 22777,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 22484,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}}}},
#     'sr': {'y_pred': 21091.213333333333,
#      'level': 4,
#      'split': [1, 11676.545454545454],
#      'n_samples': 75,
#      'gain': 658506.4793908512,
#      'sl': {'y_pred': 18562.0,
#       'level': 5,
#       'split': [1, 10956.0],
#       'n_samples': 7,
#       'gain': 1723080.1,
#       'sl': {'y_pred': 17731.8,
#        'level': 6,
#        'split': [1, 10447.727272727272],
#        'n_samples': 5,
#        'gain': 686410.7266666668,
#        'sl': {'y_pred': 18746.5,
#         'level': 7,
#         'split': [1, 10300.545454545454],
#         'n_samples': 2,
#         'gain': 567762.25,
#         'sl': {'y_pred': 17993,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 19500,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 17055.333333333332,
#         'level': 7,
#         'split': [1, 10773.90909090909],
#         'n_samples': 3,
#         'gain': 52920.8888888889,
#         'sl': {'y_pred': 16730,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 17218.0,
#          'level': 8,
#          'split': [1, 10818.90909090909],
#          'n_samples': 2,
#          'gain': 49729.0,
#          'sl': {'y_pred': 17441,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 16995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}},
#       'sr': {'y_pred': 20637.5,
#        'level': 6,
#        'split': [1, 11145.636363636364],
#        'n_samples': 2,
#        'gain': 5581406.25,
#        'sl': {'y_pred': 23000,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0},
#        'sr': {'y_pred': 18275,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0}}},
#      'sr': {'y_pred': 21351.573529411766,
#       'level': 5,
#       'split': [1, 13967.727272727272],
#       'n_samples': 68,
#       'gain': 512141.70739821903,
#       'sl': {'y_pred': 23464.14285714286,
#        'level': 6,
#        'split': [1, 12099.818181818182],
#        'n_samples': 7,
#        'gain': 2670477.551020407,
#        'sl': {'y_pred': 27467,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0},
#        'sr': {'y_pred': 22797.0,
#         'level': 7,
#         'split': [1, 13288.363636363636],
#         'n_samples': 6,
#         'gain': 724281.8,
#         'sl': {'y_pred': 23177.6,
#          'level': 8,
#          'split': [1, 12693.90909090909],
#          'n_samples': 5,
#          'gain': 1548180.8066666664,
#          'sl': {'y_pred': 22161.666666666668,
#           'level': 9,
#           'split': [1, 12425.181818181818],
#           'n_samples': 3,
#           'gain': 54230.22222222223,
#           'sl': {'y_pred': 21997.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 4.0},
#           'sr': {'y_pred': 22491,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 24701.5,
#           'level': 9,
#           'split': [1, 12893.0],
#           'n_samples': 2,
#           'gain': 493506.25,
#           'sl': {'y_pred': 23999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 25404,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 20894,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}}},
#       'sr': {'y_pred': 21109.147540983606,
#        'level': 6,
#        'split': [1, 30063.454545454544],
#        'n_samples': 61,
#        'gain': 351029.3903528699,
#        'sl': {'y_pred': 21304.836363636365,
#         'level': 7,
#         'split': [1, 15220.727272727272],
#         'n_samples': 55,
#         'gain': 82925.85867768573,
#         'sl': {'y_pred': 20394.2,
#          'level': 8,
#          'split': [1, 15130.90909090909],
#          'n_samples': 5,
#          'gain': 814458.7266666663,
#          'sl': {'y_pred': 19657.333333333332,
#           'level': 9,
#           'split': [1, 14754.363636363636],
#           'n_samples': 3,
#           'gain': 1061910.2222222225,
#           'sl': {'y_pred': 20386.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 1946025.0},
#           'sr': {'y_pred': 18200,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 21499.5,
#           'level': 9,
#           'split': [1, 15149.818181818182],
#           'n_samples': 2,
#           'gain': 250500.25,
#           'sl': {'y_pred': 20999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 22000,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 21395.9,
#          'level': 8,
#          'split': [1, 19082.636363636364],
#          'n_samples': 50,
#          'gain': 71057.62571428576,
#          'sl': {'y_pred': 21823.35714285714,
#           'level': 9,
#           'split': [1, 18480.636363636364],
#           'n_samples': 14,
#           'gain': 996213.9510204084,
#           'sl': {'y_pred': 21192.1,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 1583696.402499999},
#           'sr': {'y_pred': 23401.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 505521.0}},
#          'sr': {'y_pred': 21229.666666666668,
#           'level': 9,
#           'split': [1, 25193.0],
#           'n_samples': 36,
#           'gain': 52482.14641397307,
#           'sl': {'y_pred': 21057.434782608696,
#            'level': 10,
#            'split': -1,
#            'n_samples': 23,
#            'gain': 680173.8740075608},
#           'sr': {'y_pred': 21534.384615384617,
#            'level': 10,
#            'split': -1,
#            'n_samples': 13,
#            'gain': 195666.69822485233}}}},
#        'sr': {'y_pred': 19315.333333333332,
#         'level': 7,
#         'split': [1, 36046.90909090909],
#         'n_samples': 6,
#         'gain': 1724844.4444444445,
#         'sl': {'y_pred': 20628.666666666668,
#          'level': 8,
#          'split': [1, 30462.454545454544],
#          'n_samples': 3,
#          'gain': 927976.0555555555,
#          'sl': {'y_pred': 21991,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 19947.5,
#           'level': 9,
#           'split': [1, 31840.18181818182],
#           'n_samples': 2,
#           'gain': 425756.25,
#           'sl': {'y_pred': 19295,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 20600,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 18002.0,
#          'level': 8,
#          'split': [1, 36882.0],
#          'n_samples': 3,
#          'gain': 699744.5000000002,
#          'sl': {'y_pred': 16819,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 18593.5,
#           'level': 9,
#           'split': [1, 37087.181818181816],
#           'n_samples': 2,
#           'gain': 1969812.25,
#           'sl': {'y_pred': 19997,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 17190,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}}}}}}}}

# %%
# Aplicación de la función tree_grow usando MAE
mae_tree = tree_grow(X_train_enc, y_train, level=0, min_gain=0.001, max_depth=10, num_pct=10, criterio = "mae")
mae_tree
# Out:
# {'y_pred': 15000.0,
#  'level': 0,
#  'split': [0, 2012.0],
#  'n_samples': 7031,
#  'gain': 1077.1767885080355,
#  'sl': {'y_pred': 8737.28071379547,
#   'level': 1,
#   'split': [1, 97798.72727272728],
#   'n_samples': 1457,
#   'gain': 1109280.4742891928,
#   'sl': {'y_pred': 9891.465256797583,
#    'level': 2,
#    'split': [0, 2008.0],
#    'n_samples': 662,
#    'gain': 902634.9592679311,
#    'sl': {'y_pred': 8421.194871794873,
#     'level': 3,
#     'split': [0, 2006.0],
#     'n_samples': 195,
#     'gain': 336865.7958247354,
#     'sl': {'y_pred': 7618.9701492537315,
#      'level': 4,
#      'split': [1, 51260.0],
#      'n_samples': 67,
#      'gain': 281288.4641247627,
#      'sl': {'y_pred': 8754.416666666666,
#       'level': 5,
#       'split': [1, 39086.0],
#       'n_samples': 12,
#       'gain': 526056.166865079,
#       'sl': {'y_pred': 9612.6,
#        'level': 6,
#        'split': [2, 0.18181818181818166],
#        'n_samples': 5,
#        'gain': 507387.8400000001,
#        'sl': {'y_pred': 9031.0,
#         'level': 7,
#         'split': [1, 32355.81818181818],
#         'n_samples': 3,
#         'gain': 288800.0,
#         'sl': {'y_pred': 9791,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 8651.0,
#          'level': 8,
#          'split': [1, 36042.27272727273],
#          'n_samples': 2,
#          'gain': 62001.0,
#          'sl': {'y_pred': 8900,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 8402,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 10485.0,
#         'level': 7,
#         'split': [0, 2003.1818181818182],
#         'n_samples': 2,
#         'gain': 255025.0,
#         'sl': {'y_pred': 9980,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 10990,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}}},
#       'sr': {'y_pred': 8141.428571428572,
#        'level': 6,
#        'split': [0, 2003.090909090909],
#        'n_samples': 7,
#        'gain': 728382.9877551021,
#        'sl': {'y_pred': 6792.0,
#         'level': 7,
#         'split': [1, 39483.27272727273],
#         'n_samples': 2,
#         'gain': 39204.0,
#         'sl': {'y_pred': 6594,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 6990,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 8681.2,
#         'level': 7,
#         'split': [1, 47230.454545454544],
#         'n_samples': 5,
#         'gain': 431517.61,
#         'sl': {'y_pred': 8352.75,
#          'level': 8,
#          'split': [6, 0.09090909090909083],
#          'n_samples': 4,
#          'gain': 153860.0625,
#          'sl': {'y_pred': 7960.5,
#           'level': 9,
#           'split': [0, 2004.090909090909],
#           'n_samples': 2,
#           'gain': 756.25,
#           'sl': {'y_pred': 7933,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 7988,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 8745.0,
#           'level': 9,
#           'split': [0, 2004.090909090909],
#           'n_samples': 2,
#           'gain': 62500.0,
#           'sl': {'y_pred': 8995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 8495,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 9995,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}}}},
#      'sr': {'y_pred': 7371.236363636363,
#       'level': 5,
#       'split': [0, 2005.0],
#       'n_samples': 55,
#       'gain': 179453.71601775335,
#       'sl': {'y_pred': 6955.25,
#        'level': 6,
#        'split': [2, 0.5454545454545467],
#        'n_samples': 28,
#        'gain': 220675.44083333318,
#        'sl': {'y_pred': 6792.52,
#         'level': 7,
#         'split': [0, 2004.0],
#         'n_samples': 25,
#         'gain': 111679.65205614048,
#         'sl': {'y_pred': 6980.315789473684,
#          'level': 8,
#          'split': [0, 2000.909090909091],
#          'n_samples': 19,
#          'gain': 218689.628848437,
#          'sl': {'y_pred': 6197.8,
#           'level': 9,
#           'split': [1, 90776.72727272728],
#           'n_samples': 5,
#           'gain': 123271.20999999998,
#           'sl': {'y_pred': 6022.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 90915.02083333333},
#           'sr': {'y_pred': 6900,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 7259.785714285715,
#           'level': 9,
#           'split': [1, 88433.36363636365],
#           'n_samples': 14,
#           'gain': 141000.96003401373,
#           'sl': {'y_pred': 7413.083333333333,
#            'level': 10,
#            'split': -1,
#            'n_samples': 12,
#            'gain': 500808.5013888887},
#           'sr': {'y_pred': 6340.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 122500.0}}},
#         'sr': {'y_pred': 6197.833333333333,
#          'level': 8,
#          'split': [1, 70988.18181818182],
#          'n_samples': 6,
#          'gain': 152168.05555555553,
#          'sl': {'y_pred': 6749.5,
#           'level': 9,
#           'split': [1, 62665.818181818184],
#           'n_samples': 2,
#           'gain': 62250.25,
#           'sl': {'y_pred': 6999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 6500,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 5922.0,
#           'level': 9,
#           'split': [1, 84447.0],
#           'n_samples': 4,
#           'gain': 1776.333333333333,
#           'sl': {'y_pred': 5897.666666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 4769.38888888889},
#           'sr': {'y_pred': 5995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}},
#        'sr': {'y_pred': 8311.333333333334,
#         'level': 7,
#         'split': [1, 79383.72727272728],
#         'n_samples': 3,
#         'gain': 1421860.0555555555,
#         'sl': {'y_pred': 6625,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 9154.5,
#          'level': 8,
#          'split': [1, 80694.72727272728],
#          'n_samples': 2,
#          'gain': 711492.25,
#          'sl': {'y_pred': 9998,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 8311,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}},
#       'sr': {'y_pred': 7802.62962962963,
#        'level': 6,
#        'split': [1, 74901.54545454544],
#        'n_samples': 27,
#        'gain': 499970.75727023324,
#        'sl': {'y_pred': 8435.066666666668,
#         'level': 7,
#         'split': [1, 73916.0],
#         'n_samples': 15,
#         'gain': 137407.84683760675,
#         'sl': {'y_pred': 8580.461538461539,
#          'level': 8,
#          'split': [1, 71725.81818181818],
#          'n_samples': 13,
#          'gain': 229970.27928994037,
#          'sl': {'y_pred': 8317.8,
#           'level': 9,
#           'split': [1, 68311.18181818182],
#           'n_samples': 10,
#           'gain': 505579.55047619087,
#           'sl': {'y_pred': 8783.285714285714,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 586816.0183673471},
#           'sr': {'y_pred': 7231.666666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 132956.05555555556}},
#          'sr': {'y_pred': 9456.0,
#           'level': 9,
#           'split': [1, 72694.72727272728],
#           'n_samples': 3,
#           'gain': 1879860.5,
#           'sl': {'y_pred': 8486.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 251502.25},
#           'sr': {'y_pred': 11395,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 7490.0,
#          'level': 8,
#          'split': [1, 74043.72727272728],
#          'n_samples': 2,
#          'gain': 255025.0,
#          'sl': {'y_pred': 7995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 6985,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 7012.083333333333,
#         'level': 7,
#         'split': [1, 79522.0],
#         'n_samples': 12,
#         'gain': 134220.6824494952,
#         'sl': {'y_pred': 5797,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 7122.545454545455,
#          'level': 8,
#          'split': [1, 96848.63636363637],
#          'n_samples': 11,
#          'gain': 148973.12066115718,
#          'sl': {'y_pred': 7244.6,
#           'level': 9,
#           'split': [1, 96620.18181818182],
#           'n_samples': 10,
#           'gain': 335395.41777777777,
#           'sl': {'y_pred': 7051.555555555556,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 323386.69135802437},
#           'sr': {'y_pred': 8982,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 5902,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}}}},
#     'sr': {'y_pred': 8841.109375,
#      'level': 4,
#      'split': [1, 49103.72727272727],
#      'n_samples': 128,
#      'gain': 574810.8403180004,
#      'sl': {'y_pred': 11198.333333333334,
#       'level': 5,
#       'split': [2, 1.0],
#       'n_samples': 12,
#       'gain': 2491842.0868055564,
#       'sl': {'y_pred': 10082.125,
#        'level': 6,
#        'split': [1, 40533.36363636364],
#        'n_samples': 8,
#        'gain': 462749.92604166653,
#        'sl': {'y_pred': 10960.333333333334,
#         'level': 7,
#         'split': [1, 14535.272727272728],
#         'n_samples': 3,
#         'gain': 600.8888888888887,
#         'sl': {'y_pred': 10995,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 10943.0,
#          'level': 8,
#          'split': [1, 39051.72727272727],
#          'n_samples': 2,
#          'gain': 2704.0,
#          'sl': {'y_pred': 10891,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 10995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 9555.2,
#         'level': 7,
#         'split': [1, 44816.545454545456],
#         'n_samples': 5,
#         'gain': 518256.0100000001,
#         'sl': {'y_pred': 9195.25,
#          'level': 8,
#          'split': [1, 42056.0],
#          'n_samples': 4,
#          'gain': 477004.6875,
#          'sl': {'y_pred': 9594.0,
#           'level': 9,
#           'split': [1, 40582.63636363636],
#           'n_samples': 3,
#           'gain': 315218.0,
#           'sl': {'y_pred': 8800,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 9991.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 49.0}},
#          'sr': {'y_pred': 7999,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 10995,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}}},
#       'sr': {'y_pred': 13430.75,
#        'level': 6,
#        'split': [1, 39951.545454545456],
#        'n_samples': 4,
#        'gain': 2451573.0625,
#        'sl': {'y_pred': 14996.5,
#         'level': 7,
#         'split': [1, 32342.272727272728],
#         'n_samples': 2,
#         'gain': 2.25,
#         'sl': {'y_pred': 14998,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 14995,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 11865.0,
#         'level': 7,
#         'split': [0, 2006.090909090909],
#         'n_samples': 2,
#         'gain': 1243225.0,
#         'sl': {'y_pred': 10750,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 12980,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}}}},
#      'sr': {'y_pred': 8597.258620689656,
#       'level': 5,
#       'split': [1, 77212.90909090909],
#       'n_samples': 116,
#       'gain': 300725.74571241834,
#       'sl': {'y_pred': 9325.166666666666,
#        'level': 6,
#        'split': [2, 0.8181818181818201],
#        'n_samples': 42,
#        'gain': 223701.87777777785,
#        'sl': {'y_pred': 9026.033333333333,
#         'level': 7,
#         'split': [1, 68898.36363636363],
#         'n_samples': 30,
#         'gain': 163876.53397660796,
#         'sl': {'y_pred': 9334.052631578947,
#          'level': 8,
#          'split': [3, 0.27272727272727293],
#          'n_samples': 19,
#          'gain': 353862.06389658386,
#          'sl': {'y_pred': 10486.0,
#           'level': 9,
#           'split': [1, 60481.181818181816],
#           'n_samples': 4,
#           'gain': 262656.25,
#           'sl': {'y_pred': 10998.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 0.25},
#           'sr': {'y_pred': 9973.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 2.25}},
#          'sr': {'y_pred': 9026.866666666667,
#           'level': 9,
#           'split': [1, 64644.27272727273],
#           'n_samples': 15,
#           'gain': 349579.38962962944,
#           'sl': {'y_pred': 8544.111111111111,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 299968.15432098776},
#           'sr': {'y_pred': 9751.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 123008.00000000003}}},
#         'sr': {'y_pred': 8494.0,
#          'level': 8,
#          'split': [1, 74246.90909090909],
#          'n_samples': 11,
#          'gain': 499666.72222222236,
#          'sl': {'y_pred': 8160.777777777777,
#           'level': 9,
#           'split': [8, 0.2727272727272734],
#           'n_samples': 9,
#           'gain': 85951.186728395,
#           'sl': {'y_pred': 8057.125,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'gain': 35485.140625},
#           'sr': {'y_pred': 8990,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 9993.5,
#           'level': 9,
#           'split': [1, 76104.63636363637],
#           'n_samples': 2,
#           'gain': 30.25,
#           'sl': {'y_pred': 9988,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 9999,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}},
#        'sr': {'y_pred': 10073.0,
#         'level': 7,
#         'split': [1, 53000.0],
#         'n_samples': 12,
#         'gain': 1099680.3636363638,
#         'sl': {'y_pred': 6595,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 10389.181818181818,
#          'level': 8,
#          'split': [1, 72117.27272727274],
#          'n_samples': 11,
#          'gain': 561955.0995179064,
#          'sl': {'y_pred': 9930.125,
#           'level': 9,
#           'split': [1, 69070.54545454546],
#           'n_samples': 8,
#           'gain': 289929.796875,
#           'sl': {'y_pred': 10241.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 312500.0},
#           'sr': {'y_pred': 8997.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 6.25}},
#          'sr': {'y_pred': 11613.333333333334,
#           'level': 9,
#           'split': [1, 74315.90909090909],
#           'n_samples': 3,
#           'gain': 1309501.388888889,
#           'sl': {'y_pred': 12422.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 182756.25},
#           'sr': {'y_pred': 9995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}},
#       'sr': {'y_pred': 8184.121621621622,
#        'level': 6,
#        'split': [1, 83676.45454545454],
#        'n_samples': 74,
#        'gain': 59164.002275248524,
#        'sl': {'y_pred': 8583.8,
#         'level': 7,
#         'split': [1, 83169.36363636363],
#         'n_samples': 20,
#         'gain': 242901.12249999982,
#         'sl': {'y_pred': 8337.375,
#          'level': 8,
#          'split': [1, 80181.45454545454],
#          'n_samples': 16,
#          'gain': 403140.00223214296,
#          'sl': {'y_pred': 8897.333333333334,
#           'level': 9,
#           'split': [7, 0.2727272727272734],
#           'n_samples': 9,
#           'gain': 843484.013888889,
#           'sl': {'y_pred': 8572.625,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'gain': 81420.08437499998},
#           'sr': {'y_pred': 11495,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 7617.428571428572,
#           'level': 9,
#           'split': [8, 0.45454545454545503],
#           'n_samples': 7,
#           'gain': 247022.0544217687,
#           'sl': {'y_pred': 7820.333333333333,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 62069.388888888876},
#           'sr': {'y_pred': 6400,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 9569.5,
#          'level': 8,
#          'split': [0, 2006.090909090909],
#          'n_samples': 4,
#          'gain': 141000.25,
#          'sl': {'y_pred': 9945.0,
#           'level': 9,
#           'split': [1, 83504.63636363637],
#           'n_samples': 2,
#           'gain': 2025.0,
#           'sl': {'y_pred': 9990,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 9900,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 9194.0,
#           'level': 9,
#           'split': [1, 83193.63636363637],
#           'n_samples': 2,
#           'gain': 41616.0,
#           'sl': {'y_pred': 9398,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 8990,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}},
#        'sr': {'y_pred': 8036.092592592592,
#         'level': 7,
#         'split': [2, 0.5454545454545467],
#         'n_samples': 54,
#         'gain': 73997.193420914,
#         'sl': {'y_pred': 8204.794871794871,
#          'level': 8,
#          'split': [1, 95481.81818181819],
#          'n_samples': 39,
#          'gain': 97051.35718981875,
#          'sl': {'y_pred': 8350.5,
#           'level': 9,
#           'split': [1, 94127.36363636363],
#           'n_samples': 32,
#           'gain': 158721.641025641,
#           'sl': {'y_pred': 8159.115384615385,
#            'level': 10,
#            'split': -1,
#            'n_samples': 26,
#            'gain': 91754.62343852711},
#           'sr': {'y_pred': 9179.833333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 658966.0055555562}},
#          'sr': {'y_pred': 7538.714285714285,
#           'level': 9,
#           'split': [0, 2006.5454545454545],
#           'n_samples': 7,
#           'gain': 395633.41836734704,
#           'sl': {'y_pred': 5998,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 7795.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 163262.4499999999}}},
#         'sr': {'y_pred': 7597.466666666666,
#          'level': 8,
#          'split': [1, 85270.54545454546],
#          'n_samples': 15,
#          'gain': 272375.47313131334,
#          'sl': {'y_pred': 6732.0,
#           'level': 9,
#           'split': [1, 83740.81818181818],
#           'n_samples': 4,
#           'gain': 181056.33333333337,
#           'sl': {'y_pred': 5995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 6977.666666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 809416.0555555555}},
#          'sr': {'y_pred': 7912.181818181818,
#           'level': 9,
#           'split': [1, 87337.45454545454],
#           'n_samples': 11,
#           'gain': 199708.2851239671,
#           'sl': {'y_pred': 6499,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 8053.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 420552.2499999999}}}}}}}},
#    'sr': {'y_pred': 10505.389721627409,
#     'level': 3,
#     'split': [1, 64289.72727272727],
#     'n_samples': 467,
#     'gain': 504235.0878509972,
#     'sl': {'y_pred': 11661.0,
#      'level': 4,
#      'split': [2, 1.0],
#      'n_samples': 128,
#      'gain': 127187.17020089272,
#      'sl': {'y_pred': 11526.205357142857,
#       'level': 5,
#       'split': [0, 2009.1818181818182],
#       'n_samples': 112,
#       'gain': 464241.151607879,
#       'sl': {'y_pred': 10107.857142857143,
#        'level': 6,
#        'split': [1, 53685.36363636363],
#        'n_samples': 21,
#        'gain': 198088.69387755124,
#        'sl': {'y_pred': 10457.0,
#         'level': 7,
#         'split': [0, 2008.1818181818182],
#         'n_samples': 13,
#         'gain': 82477.63333333307,
#         'sl': {'y_pred': 9932.666666666666,
#          'level': 8,
#          'split': [1, 28379.090909090908],
#          'n_samples': 3,
#          'gain': 172088.88888888888,
#          'sl': {'y_pred': 9346,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 10226.0,
#           'level': 9,
#           'split': [1, 33465.63636363636],
#           'n_samples': 2,
#           'gain': 75076.0,
#           'sl': {'y_pred': 9952,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10500,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 10614.3,
#          'level': 8,
#          'split': [1, 52637.72727272727],
#          'n_samples': 10,
#          'gain': 631866.0100000005,
#          'sl': {'y_pred': 10349.333333333334,
#           'level': 9,
#           'split': [1, 50152.63636363637],
#           'n_samples': 9,
#           'gain': 749904.2222222222,
#           'sl': {'y_pred': 10655.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'gain': 257472.32142857136},
#           'sr': {'y_pred': 7900,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 12999,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 9540.5,
#         'level': 7,
#         'split': [0, 2008.6363636363637],
#         'n_samples': 8,
#         'gain': 434256.03571428545,
#         'sl': {'y_pred': 7797,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 9789.57142857143,
#          'level': 8,
#          'split': [1, 60447.545454545456],
#          'n_samples': 7,
#          'gain': 563890.6139455786,
#          'sl': {'y_pred': 9139.25,
#           'level': 9,
#           'split': [1, 58153.36363636363],
#           'n_samples': 4,
#           'gain': 900090.1875,
#           'sl': {'y_pred': 9687.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 81204.5},
#           'sr': {'y_pred': 7496,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 10656.666666666666,
#           'level': 9,
#           'split': [3, 0.18181818181818182],
#           'n_samples': 3,
#           'gain': 228938.88888888888,
#           'sl': {'y_pred': 9980,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 0.0}}}}},
#       'sr': {'y_pred': 11853.516483516483,
#        'level': 6,
#        'split': [1, 51648.0],
#        'n_samples': 91,
#        'gain': 50849.02912255749,
#        'sl': {'y_pred': 12102.536585365853,
#         'level': 7,
#         'split': [0, 2011.0],
#         'n_samples': 41,
#         'gain': 494212.3453570267,
#         'sl': {'y_pred': 13340.3,
#          'level': 8,
#          'split': [6, 0.3636363636363642],
#          'n_samples': 10,
#          'gain': 528383.6099999999,
#          'sl': {'y_pred': 13703.75,
#           'level': 9,
#           'split': [1, 32696.363636363636],
#           'n_samples': 8,
#           'gain': 278324.7041666666,
#           'sl': {'y_pred': 13022.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 549850.888888889},
#           'sr': {'y_pred': 14112.4,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 374788.84}},
#          'sr': {'y_pred': 11886.5,
#           'level': 9,
#           'split': [1, 37855.63636363636],
#           'n_samples': 2,
#           'gain': 149382.25,
#           'sl': {'y_pred': 12273,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 11500,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 11703.258064516129,
#          'level': 8,
#          'split': [8, 0.2727272727272734],
#          'n_samples': 31,
#          'gain': 390489.46950101596,
#          'sl': {'y_pred': 11498.714285714286,
#           'level': 9,
#           'split': [1, 40237.27272727273],
#           'n_samples': 28,
#           'gain': 456638.5905895692,
#           'sl': {'y_pred': 10592.1,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 379086.49},
#           'sr': {'y_pred': 12002.388888888889,
#            'level': 10,
#            'split': -1,
#            'n_samples': 18,
#            'gain': 103259.87654320989}},
#          'sr': {'y_pred': 13612.333333333334,
#           'level': 9,
#           'split': [1, 31573.636363636364],
#           'n_samples': 3,
#           'gain': 1567040.0555555555,
#           'sl': {'y_pred': 11842,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 14497.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 2242506.25}}}},
#        'sr': {'y_pred': 11649.32,
#         'level': 7,
#         'split': [1, 53171.90909090909],
#         'n_samples': 50,
#         'gain': 46179.14471111074,
#         'sl': {'y_pred': 12294.0,
#          'level': 8,
#          'split': [1, 52819.545454545456],
#          'n_samples': 5,
#          'gain': 1476225.0,
#          'sl': {'y_pred': 12901.5,
#           'level': 9,
#           'split': [1, 51722.63636363636],
#           'n_samples': 4,
#           'gain': 209880.75,
#           'sl': {'y_pred': 13695,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 12637.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 63724.5}},
#          'sr': {'y_pred': 9864,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 11577.68888888889,
#          'level': 8,
#          'split': [1, 55582.0],
#          'n_samples': 45,
#          'gain': 255230.1033453783,
#          'sl': {'y_pred': 9960.25,
#           'level': 9,
#           'split': [1, 53263.545454545456],
#           'n_samples': 4,
#           'gain': 307360.0208333334,
#           'sl': {'y_pred': 9000,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10280.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 250396.05555555556}},
#          'sr': {'y_pred': 11735.487804878048,
#           'level': 9,
#           'split': [1, 63484.27272727273],
#           'n_samples': 41,
#           'gain': 42332.79187501012,
#           'sl': {'y_pred': 11667.837837837838,
#            'level': 10,
#            'split': -1,
#            'n_samples': 37,
#            'gain': 53949.879739468684},
#           'sr': {'y_pred': 12361.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 2285950.5208333335}}}}}},
#      'sr': {'y_pred': 12604.5625,
#       'level': 5,
#       'split': [1, 29012.18181818182],
#       'n_samples': 16,
#       'gain': 2757470.438058036,
#       'sl': {'y_pred': 16998.0,
#        'level': 6,
#        'split': [1, 17229.272727272728],
#        'n_samples': 2,
#        'gain': 1000000.0,
#        'sl': {'y_pred': 15998,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0},
#        'sr': {'y_pred': 17998,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0}},
#       'sr': {'y_pred': 11976.92857142857,
#        'level': 6,
#        'split': [1, 48220.818181818184],
#        'n_samples': 14,
#        'gain': 313608.12346938765,
#        'sl': {'y_pred': 11225.6,
#         'level': 7,
#         'split': [1, 44121.181818181816],
#         'n_samples': 5,
#         'gain': 1403751.04,
#         'sl': {'y_pred': 11818.0,
#          'level': 8,
#          'split': [1, 42631.0],
#          'n_samples': 4,
#          'gain': 225776.33333333334,
#          'sl': {'y_pred': 12092.333333333334,
#           'level': 9,
#           'split': [0, 2008.5454545454545],
#           'n_samples': 3,
#           'gain': 21562.72222222222,
#           'sl': {'y_pred': 12300,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 11988.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 132.25}},
#          'sr': {'y_pred': 10995,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 8856,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 12394.333333333334,
#         'level': 7,
#         'split': [0, 2008.6363636363637],
#         'n_samples': 9,
#         'gain': 760760.0222222223,
#         'sl': {'y_pred': 13369.5,
#          'level': 8,
#          'split': [1, 56659.72727272727],
#          'n_samples': 4,
#          'gain': 770884.0,
#          'sl': {'y_pred': 14247.5,
#           'level': 9,
#           'split': [1, 49365.818181818184],
#           'n_samples': 2,
#           'gain': 5073756.25,
#           'sl': {'y_pred': 11995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 16500,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 12491.5,
#           'level': 9,
#           'split': [1, 62196.63636363636],
#           'n_samples': 2,
#           'gain': 253512.25,
#           'sl': {'y_pred': 12995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 11988,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 11614.2,
#          'level': 8,
#          'split': [0, 2010.2727272727273],
#          'n_samples': 5,
#          'gain': 1411106.4099999997,
#          'sl': {'y_pred': 11020.25,
#           'level': 9,
#           'split': [1, 61189.818181818184],
#           'n_samples': 4,
#           'gain': 196480.02083333337,
#           'sl': {'y_pred': 10764.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 297477.5555555555},
#           'sr': {'y_pred': 11788,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 13990,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}}}},
#     'sr': {'y_pred': 10069.053097345133,
#      'level': 4,
#      'split': [0, 2010.0],
#      'n_samples': 339,
#      'gain': 192796.23313530372,
#      'sl': {'y_pred': 9439.756756756757,
#       'level': 5,
#       'split': [1, 91364.0],
#       'n_samples': 111,
#       'gain': 119713.49824728188,
#       'sl': {'y_pred': 9606.888888888889,
#        'level': 6,
#        'split': [2, 1.0],
#        'n_samples': 90,
#        'gain': 41075.65582248918,
#        'sl': {'y_pred': 9512.648648648648,
#         'level': 7,
#         'split': [0, 2009.0],
#         'n_samples': 74,
#         'gain': 44930.666989565594,
#         'sl': {'y_pred': 9175.904761904761,
#          'level': 8,
#          'split': [1, 87070.72727272728],
#          'n_samples': 21,
#          'gain': 49378.37188208604,
#          'sl': {'y_pred': 9248.0,
#           'level': 9,
#           'split': [1, 82616.36363636363],
#           'n_samples': 19,
#           'gain': 57811.88235294109,
#           'sl': {'y_pred': 9165.529411764706,
#            'level': 10,
#            'split': -1,
#            'n_samples': 17,
#            'gain': 60779.1981545561},
#           'sr': {'y_pred': 9949.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 2401.0}},
#          'sr': {'y_pred': 8491.0,
#           'level': 9,
#           'split': [1, 89914.0],
#           'n_samples': 2,
#           'gain': 246016.0,
#           'sl': {'y_pred': 8987,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 7995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 9646.075471698114,
#          'level': 8,
#          'split': [1, 74730.54545454546],
#          'n_samples': 53,
#          'gain': 81078.24511501286,
#          'sl': {'y_pred': 9192.866666666667,
#           'level': 9,
#           'split': [1, 71480.0],
#           'n_samples': 15,
#           'gain': 81746.33373737376,
#           'sl': {'y_pred': 9020.454545454546,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 104541.32975206609},
#           'sr': {'y_pred': 9667.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 459006.25}},
#          'sr': {'y_pred': 9824.973684210527,
#           'level': 9,
#           'split': [1, 88298.81818181818],
#           'n_samples': 38,
#           'gain': 149575.61257451726,
#           'sl': {'y_pred': 9641.193548387097,
#            'level': 10,
#            'split': -1,
#            'n_samples': 31,
#            'gain': 168091.50139532704},
#           'sr': {'y_pred': 10638.857142857143,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 3240211.665306122}}}},
#        'sr': {'y_pred': 10042.75,
#         'level': 7,
#         'split': [1, 79473.54545454546],
#         'n_samples': 16,
#         'gain': 379612.60416666674,
#         'sl': {'y_pred': 10838.166666666666,
#          'level': 8,
#          'split': [1, 77107.18181818182],
#          'n_samples': 6,
#          'gain': 926938.2722222223,
#          'sl': {'y_pred': 10407.6,
#           'level': 9,
#           'split': [1, 76530.0],
#           'n_samples': 5,
#           'gain': 1455159.6899999997,
#           'sl': {'y_pred': 11010.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 343916.0208333333},
#           'sr': {'y_pred': 7995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 12991,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 9565.5,
#          'level': 8,
#          'split': [1, 88990.90909090909],
#          'n_samples': 10,
#          'gain': 647858.6785714284,
#          'sl': {'y_pred': 9038.57142857143,
#           'level': 9,
#           'split': [0, 2008.3636363636363],
#           'n_samples': 7,
#           'gain': 587993.2163265309,
#           'sl': {'y_pred': 8553.6,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 106145.6399999999},
#           'sr': {'y_pred': 10251.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 553536.0}},
#          'sr': {'y_pred': 10795.0,
#           'level': 9,
#           'split': [1, 91201.63636363637],
#           'n_samples': 3,
#           'gain': 845000.0,
#           'sl': {'y_pred': 11445.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 202500.0},
#           'sr': {'y_pred': 9495,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}},
#       'sr': {'y_pred': 8723.47619047619,
#        'level': 6,
#        'split': [1, 92295.45454545454],
#        'n_samples': 21,
#        'gain': 496370.0689819788,
#        'sl': {'y_pred': 10895.0,
#         'level': 7,
#         'split': [1, 91406.72727272728],
#         'n_samples': 2,
#         'gain': 40000.0,
#         'sl': {'y_pred': 11095,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 10695,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 8494.894736842105,
#         'level': 7,
#         'split': [3, 0.8181818181818166],
#         'n_samples': 19,
#         'gain': 192381.76669744565,
#         'sl': {'y_pred': 8911.0,
#          'level': 8,
#          'split': [1, 97337.72727272728],
#          'n_samples': 10,
#          'gain': 861184.0,
#          'sl': {'y_pred': 8601.666666666666,
#           'level': 9,
#           'split': [4, 0.5454545454545459],
#           'n_samples': 9,
#           'gain': 349917.46031746035,
#           'sl': {'y_pred': 8917.857142857143,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 435020.4081632653},
#           'sr': {'y_pred': 7495.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 250000.0}},
#          'sr': {'y_pred': 11695,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}},
#         'sr': {'y_pred': 8032.555555555556,
#          'level': 8,
#          'split': [1, 96728.54545454546],
#          'n_samples': 9,
#          'gain': 176089.20723104046,
#          'sl': {'y_pred': 8256.857142857143,
#           'level': 9,
#           'split': [1, 95376.90909090909],
#           'n_samples': 7,
#           'gain': 503523.431972789,
#           'sl': {'y_pred': 7967.166666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 254520.25000000006},
#           'sr': {'y_pred': 9995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 7247.5,
#           'level': 9,
#           'split': [0, 2008.090909090909],
#           'n_samples': 2,
#           'gain': 63756.25,
#           'sl': {'y_pred': 7500,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 6995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}}},
#      'sr': {'y_pred': 10375.421052631578,
#       'level': 5,
#       'split': [1, 91629.45454545454],
#       'n_samples': 228,
#       'gain': 222411.42716985382,
#       'sl': {'y_pred': 10663.638554216868,
#        'level': 6,
#        'split': [6, 1.0],
#        'n_samples': 166,
#        'gain': 34564.22497119731,
#        'sl': {'y_pred': 10749.175182481751,
#         'level': 7,
#         'split': [1, 74625.18181818182],
#         'n_samples': 137,
#         'gain': 5590.146339372499,
#         'sl': {'y_pred': 10847.8,
#          'level': 8,
#          'split': [1, 70779.45454545454],
#          'n_samples': 50,
#          'gain': 38657.13391304342,
#          'sl': {'y_pred': 10666.333333333334,
#           'level': 9,
#           'split': [1, 69626.36363636363],
#           'n_samples': 27,
#           'gain': 16958.680555555853,
#           'sl': {'y_pred': 10712.375,
#            'level': 10,
#            'split': -1,
#            'n_samples': 24,
#            'gain': 34875.09780092584},
#           'sr': {'y_pred': 10298.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 79202.0}},
#          'sr': {'y_pred': 11060.826086956522,
#           'level': 9,
#           'split': [1, 71164.0],
#           'n_samples': 23,
#           'gain': 191450.5536051856,
#           'sl': {'y_pred': 9643.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 24649.0},
#           'sr': {'y_pred': 11195.857142857143,
#            'level': 10,
#            'split': -1,
#            'n_samples': 21,
#            'gain': 421744.6450053705}}},
#         'sr': {'y_pred': 10692.494252873563,
#          'level': 8,
#          'split': [1, 78631.0],
#          'n_samples': 87,
#          'gain': 29821.013627798297,
#          'sl': {'y_pred': 10412.708333333334,
#           'level': 9,
#           'split': [1, 75761.45454545454],
#           'n_samples': 24,
#           'gain': 176555.56800073083,
#           'sl': {'y_pred': 11231.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 160589.76},
#           'sr': {'y_pred': 10197.157894736842,
#            'level': 10,
#            'split': -1,
#            'n_samples': 19,
#            'gain': 170446.15618380345}},
#          'sr': {'y_pred': 10799.079365079366,
#           'level': 9,
#           'split': [1, 80916.81818181818],
#           'n_samples': 63,
#           'gain': 60046.44009085093,
#           'sl': {'y_pred': 11304.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 12,
#            'gain': 564453.1250000001},
#           'sr': {'y_pred': 10680.21568627451,
#            'level': 10,
#            'split': -1,
#            'n_samples': 51,
#            'gain': 75351.95036000153}}}},
#        'sr': {'y_pred': 10259.551724137931,
#         'level': 7,
#         'split': [0, 2011.0],
#         'n_samples': 29,
#         'gain': 351676.640756469,
#         'sl': {'y_pred': 9645.714285714286,
#          'level': 8,
#          'split': [1, 84089.72727272728],
#          'n_samples': 14,
#          'gain': 114465.6548752833,
#          'sl': {'y_pred': 9897.888888888889,
#           'level': 9,
#           'split': [1, 76441.45454545454],
#           'n_samples': 9,
#           'gain': 38417.48209876544,
#           'sl': {'y_pred': 9678.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 352775.5208333334},
#           'sr': {'y_pred': 10073.2,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 65437.92666666665}},
#          'sr': {'y_pred': 9191.8,
#           'level': 9,
#           'split': [1, 86815.09090909091],
#           'n_samples': 5,
#           'gain': 325547.6266666667,
#           'sl': {'y_pred': 8493.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 4.0},
#           'sr': {'y_pred': 9657.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 374689.3888888889}}},
#         'sr': {'y_pred': 10832.466666666667,
#          'level': 8,
#          'split': [1, 76400.72727272728],
#          'n_samples': 15,
#          'gain': 308428.9458585859,
#          'sl': {'y_pred': 9911.5,
#           'level': 9,
#           'split': [1, 65141.09090909091],
#           'n_samples': 4,
#           'gain': 197376.75,
#           'sl': {'y_pred': 10681,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 9655.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 338664.5}},
#          'sr': {'y_pred': 11167.363636363636,
#           'level': 9,
#           'split': [1, 89903.36363636363],
#           'n_samples': 11,
#           'gain': 453700.28696051426,
#           'sl': {'y_pred': 11484.888888888889,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'gain': 164859.72574955912},
#           'sr': {'y_pred': 9738.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 26082.25}}}}},
#       'sr': {'y_pred': 9603.741935483871,
#        'level': 6,
#        'split': [1, 96234.18181818182],
#        'n_samples': 62,
#        'gain': 145138.87654651818,
#        'sl': {'y_pred': 9896.307692307691,
#         'level': 7,
#         'split': [0, 2011.0],
#         'n_samples': 39,
#         'gain': 163856.10650887573,
#         'sl': {'y_pred': 9323.846153846154,
#          'level': 8,
#          'split': [3, 0.09090909090909083],
#          'n_samples': 13,
#          'gain': 157033.504303389,
#          'sl': {'y_pred': 8394.5,
#           'level': 9,
#           'split': [1, 93602.27272727272],
#           'n_samples': 2,
#           'gain': 159600.25,
#           'sl': {'y_pred': 8794,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 7995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 9492.818181818182,
#           'level': 9,
#           'split': [1, 94200.90909090909],
#           'n_samples': 11,
#           'gain': 66180.83707201865,
#           'sl': {'y_pred': 9152.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 162168.75},
#           'sr': {'y_pred': 9687.285714285714,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'gain': 330276.5850340138}}},
#         'sr': {'y_pred': 10182.538461538461,
#          'level': 8,
#          'split': [1, 92118.63636363637],
#          'n_samples': 26,
#          'gain': 58109.3354772313,
#          'sl': {'y_pred': 10850.0,
#           'level': 9,
#           'split': [1, 92064.27272727272],
#           'n_samples': 3,
#           'gain': 148512.5,
#           'sl': {'y_pred': 10577.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 40602.25},
#           'sr': {'y_pred': 11395,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 10095.478260869566,
#           'level': 9,
#           'split': [1, 93356.0],
#           'n_samples': 23,
#           'gain': 161247.25786074367,
#           'sl': {'y_pred': 9545.625,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'gain': 154813.0010416666},
#           'sr': {'y_pred': 10388.733333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 15,
#            'gain': 221495.73444444442}}}},
#        'sr': {'y_pred': 9107.652173913044,
#         'level': 7,
#         'split': [6, 1.0],
#         'n_samples': 23,
#         'gain': 85951.03971607541,
#         'sl': {'y_pred': 9281.823529411764,
#          'level': 8,
# ...
#           'sl': {'y_pred': 14560.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 572033.3333333334},
#           'sr': {'y_pred': 11593.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 486755.5555555556}}}}},
#       'sr': {'y_pred': 15362.914285714285,
#        'level': 6,
#        'split': [1, 67281.90909090909],
#        'n_samples': 35,
#        'gain': 804301.4865306113,
#        'sl': {'y_pred': 17156.571428571428,
#         'level': 7,
#         'split': [1, 67071.36363636363],
#         'n_samples': 7,
#         'gain': 1325802.8877551025,
#         'sl': {'y_pred': 16686.5,
#          'level': 8,
#          'split': [0, 2014.2727272727273],
#          'n_samples': 6,
#          'gain': 414521.361111111,
#          'sl': {'y_pred': 16042.666666666666,
#           'level': 9,
#           'split': [1, 66293.36363636363],
#           'n_samples': 3,
#           'gain': 124168.05555555556,
#           'sl': {'y_pred': 16541,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 15793.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 39006.25}},
#          'sr': {'y_pred': 17330.333333333332,
#           'level': 9,
#           'split': [1, 66220.45454545454],
#           'n_samples': 3,
#           'gain': 684060.0555555556,
#           'sl': {'y_pred': 16745.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 1551270.25},
#           'sr': {'y_pred': 18500,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 19977,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0}},
#        'sr': {'y_pred': 14914.5,
#         'level': 7,
#         'split': [1, 85582.90909090909],
#         'n_samples': 28,
#         'gain': 401791.3586956528,
#         'sl': {'y_pred': 15210.04347826087,
#          'level': 8,
#          'split': [0, 2015.0],
#          'n_samples': 23,
#          'gain': 120698.8317723549,
#          'sl': {'y_pred': 14877.416666666666,
#           'level': 9,
#           'split': [1, 69159.0],
#           'n_samples': 12,
#           'gain': 350514.5006313133,
#           'sl': {'y_pred': 16841,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 14698.90909090909,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'gain': 734902.8099173554}},
#          'sr': {'y_pred': 15572.90909090909,
#           'level': 9,
#           'split': [1, 69122.90909090909],
#           'n_samples': 11,
#           'gain': 972330.2493112944,
#           'sl': {'y_pred': 13962.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 433690.888888889},
#           'sr': {'y_pred': 16176.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'gain': 471252.00892857136}}},
#         'sr': {'y_pred': 13555.0,
#          'level': 8,
#          'split': [1, 89650.45454545454],
#          'n_samples': 5,
#          'gain': 1627604.166666667,
#          'sl': {'y_pred': 11992.5,
#           'level': 9,
#           'split': [0, 2014.090909090909],
#           'n_samples': 2,
#           'gain': 995006.25,
#           'sl': {'y_pred': 12990,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 14596.666666666666,
#           'level': 9,
#           'split': [0, 2014.090909090909],
#           'n_samples': 3,
#           'gain': 2880800.0555555555,
#           'sl': {'y_pred': 13396.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 265740.25},
#           'sr': {'y_pred': 16997,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}}}},
#     'sr': {'y_pred': 10981.751322751323,
#      'level': 4,
#      'split': [1, 141100.18181818182],
#      'n_samples': 189,
#      'gain': 310335.677059344,
#      'sl': {'y_pred': 11162.491228070176,
#       'level': 5,
#       'split': [0, 2014.0],
#       'n_samples': 171,
#       'gain': 276606.4451142689,
#       'sl': {'y_pred': 10910.143884892086,
#        'level': 6,
#        'split': [1, 113298.36363636363],
#        'n_samples': 139,
#        'gain': 102906.38756583282,
#        'sl': {'y_pred': 11106.910891089108,
#         'level': 7,
#         'split': [1, 94084.72727272728],
#         'n_samples': 101,
#         'gain': 58976.57170273177,
#         'sl': {'y_pred': 11839.5,
#          'level': 8,
#          'split': [1, 93158.18181818182],
#          'n_samples': 10,
#          'gain': 647507.4404761905,
#          'sl': {'y_pred': 13068.666666666666,
#           'level': 9,
#           'split': [0, 2012.090909090909],
#           'n_samples': 3,
#           'gain': 2053013.388888889,
#           'sl': {'y_pred': 12055.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 58322.25},
#           'sr': {'y_pred': 15095,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 11312.714285714286,
#           'level': 9,
#           'split': [1, 93656.27272727272],
#           'n_samples': 7,
#           'gain': 115864.82312925183,
#           'sl': {'y_pred': 10919.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 1014837.5555555556},
#           'sr': {'y_pred': 11607.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'gain': 626472.25}}},
#         'sr': {'y_pred': 11026.406593406593,
#          'level': 8,
#          'split': [6, 1.0],
#          'n_samples': 91,
#          'gain': 105718.11884413077,
#          'sl': {'y_pred': 11170.855263157895,
#           'level': 9,
#           'split': [3, 1.0],
#           'n_samples': 76,
#           'gain': 77838.36437116354,
#           'sl': {'y_pred': 11480.941176470587,
#            'level': 10,
#            'split': -1,
#            'n_samples': 34,
#            'gain': 276206.63787966175},
#           'sr': {'y_pred': 10919.833333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 42,
#            'gain': 67522.89546783618}},
#          'sr': {'y_pred': 10294.533333333333,
#           'level': 9,
#           'split': [0, 2013.0],
#           'n_samples': 15,
#           'gain': 135998.508888889,
#           'sl': {'y_pred': 9773.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'gain': 164672.66666666666},
#           'sr': {'y_pred': 10555.3,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'gain': 144851.65761904768}}}},
#        'sr': {'y_pred': 10387.157894736842,
#         'level': 7,
#         'split': [2, 1.0],
#         'n_samples': 38,
#         'gain': 154084.16358599835,
#         'sl': {'y_pred': 10234.363636363636,
#          'level': 8,
#          'split': [1, 132463.9090909091],
#          'n_samples': 33,
#          'gain': 196342.8958269565,
#          'sl': {'y_pred': 10025.481481481482,
#           'level': 9,
#           'split': [5, 0.6363636363636402],
#           'n_samples': 27,
#           'gain': 132136.07681755838,
#           'sl': {'y_pred': 10154.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 24,
#            'gain': 33907.61249999993},
#           'sr': {'y_pred': 8997.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 502670.22222222213}},
#          'sr': {'y_pred': 11174.333333333334,
#           'level': 9,
#           'split': [1, 138372.0909090909],
#           'n_samples': 6,
#           'gain': 342225.0,
#           'sl': {'y_pred': 11759.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 289053.3888888889},
#           'sr': {'y_pred': 10589.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 173656.88888888893}}},
#         'sr': {'y_pred': 11395.6,
#          'level': 8,
#          'split': [1, 115304.0],
#          'n_samples': 5,
#          'gain': 898324.8399999994,
#          'sl': {'y_pred': 9500,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 11869.5,
#           'level': 9,
#           'split': [1, 132193.18181818182],
#           'n_samples': 4,
#           'gain': 1871510.0833333333,
#           'sl': {'y_pred': 12659.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 677836.0555555556},
#           'sr': {'y_pred': 9500,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}}}},
#       'sr': {'y_pred': 12258.625,
#        'level': 6,
#        'split': [1, 109577.54545454546],
#        'n_samples': 32,
#        'gain': 472581.9463315215,
#        'sl': {'y_pred': 12688.652173913044,
#         'level': 7,
#         'split': [8, 1.0],
#         'n_samples': 23,
#         'gain': 237261.04091632692,
#         'sl': {'y_pred': 12465.157894736842,
#          'level': 8,
#          'split': [5, 0.36363636363636687],
#          'n_samples': 19,
#          'gain': 209095.29085872532,
#          'sl': {'y_pred': 12622.0,
#           'level': 9,
#           'split': [1, 93915.36363636363],
#           'n_samples': 17,
#           'gain': 235498.80000000028,
#           'sl': {'y_pred': 13951.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 2304.0},
#           'sr': {'y_pred': 12444.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 15,
#            'gain': 328660.81185185164}},
#          'sr': {'y_pred': 11132.0,
#           'level': 9,
#           'split': [1, 94471.81818181818],
#           'n_samples': 2,
#           'gain': 732736.0,
#           'sl': {'y_pred': 11988,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10276,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 13750.25,
#          'level': 8,
#          'split': [0, 2014.1818181818182],
#          'n_samples': 4,
#          'gain': 749750.020833333,
#          'sl': {'y_pred': 13250.333333333334,
#           'level': 9,
#           'split': [1, 97210.90909090909],
#           'n_samples': 3,
#           'gain': 1521930.8888888895,
#           'sl': {'y_pred': 14995,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 12378.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 1923769.0}},
#          'sr': {'y_pred': 15250,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 11159.666666666666,
#         'level': 7,
#         'split': [6, 0.5454545454545459],
#         'n_samples': 9,
#         'gain': 1281289.174603175,
#         'sl': {'y_pred': 11764.714285714286,
#          'level': 8,
#          'split': [1, 123967.90909090909],
#          'n_samples': 7,
#          'gain': 1435976.8897959183,
#          'sl': {'y_pred': 12522.6,
#           'level': 9,
#           'split': [1, 112406.36363636363],
#           'n_samples': 5,
#           'gain': 961760.8066666666,
#           'sl': {'y_pred': 11321.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 395012.25},
#           'sr': {'y_pred': 13323.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'gain': 225568.0555555556}},
#          'sr': {'y_pred': 9870.0,
#           'level': 9,
#           'split': [1, 127476.18181818182],
#           'n_samples': 2,
#           'gain': 756900.0,
#           'sl': {'y_pred': 9000,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 10740,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 9042.0,
#          'level': 8,
#          'split': [1, 111909.0],
#          'n_samples': 2,
#          'gain': 915849.0,
#          'sl': {'y_pred': 8085,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 9999,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}}},
#      'sr': {'y_pred': 9264.722222222223,
#       'level': 5,
#       'split': [1, 149163.54545454544],
#       'n_samples': 18,
#       'gain': 700244.585898669,
#       'sl': {'y_pred': 10313.714285714286,
#        'level': 6,
#        'split': [0, 2014.4545454545455],
#        'n_samples': 7,
#        'gain': 471120.2755102042,
#        'sl': {'y_pred': 10033.5,
#         'level': 7,
#         'split': [2, 0.18181818181818166],
#         'n_samples': 6,
#         'gain': 245350.12500000003,
#         'sl': {'y_pred': 9683.25,
#          'level': 8,
#          'split': [1, 147243.63636363635],
#          'n_samples': 4,
#          'gain': 96876.5625,
#          'sl': {'y_pred': 9372.0,
#           'level': 9,
#           'split': [0, 2012.1818181818182],
#           'n_samples': 2,
#           'gain': 381924.0,
#           'sl': {'y_pred': 8754,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 9990,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}},
#          'sr': {'y_pred': 9994.5,
#           'level': 9,
#           'split': [0, 2012.090909090909],
#           'n_samples': 2,
#           'gain': 12.25,
#           'sl': {'y_pred': 9998,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0},
#           'sr': {'y_pred': 9991,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'gain': 0}}},
#         'sr': {'y_pred': 10734.0,
#          'level': 8,
#          'split': [1, 141791.9090909091],
#          'n_samples': 2,
#          'gain': 59536.0,
#          'sl': {'y_pred': 10490,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0},
#          'sr': {'y_pred': 10978,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}},
#        'sr': {'y_pred': 11995,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0}},
#       'sr': {'y_pred': 8597.181818181818,
#        'level': 6,
#        'split': [1, 155889.54545454544],
#        'n_samples': 11,
#        'gain': 276617.37603305787,
#        'sl': {'y_pred': 6934,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'gain': 0},
#        'sr': {'y_pred': 8763.5,
#         'level': 7,
#         'split': [1, 156441.54545454544],
#         'n_samples': 10,
#         'gain': 167417.36111111118,
#         'sl': {'y_pred': 9991,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'gain': 0},
#         'sr': {'y_pred': 8627.111111111111,
#          'level': 8,
#          'split': [5, 0.2727272727272734],
#          'n_samples': 9,
#          'gain': 125778.98765432092,
#          'sl': {'y_pred': 8752.5,
#           'level': 9,
#           'split': [1, 158214.63636363635],
#           'n_samples': 8,
#           'gain': 90480.33333333334,
#           'sl': {'y_pred': 8231.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'gain': 59292.25},
#           'sr': {'y_pred': 8926.166666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'gain': 53901.361111111095}},
#          'sr': {'y_pred': 7624,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'gain': 0}}}}}}}}}}

# %%
# Definición de la función tree_predict para hacer predicciones según las variables 'X' y el árbol 'tree'

def tree_predict(X, tree):
    predicted = np.ones(X.shape[0])

    # Revisar si es el nodo final
    if tree['split'] == -1:
        predicted = predicted * tree['y_pred']
    else:
        j, split = tree['split']
        filter_l = (X.iloc[:, j] < split)
        X_l = X.loc[filter_l]
        X_r = X.loc[~filter_l]

        if X_l.shape[0] == 0:  # Si el nodo izquierdo está vacio solo continua con el derecho 
            predicted[~filter_l] = tree_predict(X_r, tree['sr'])
        elif X_r.shape[0] == 0:  #  Si el nodo derecho está vacio solo continua con el izquierdo
            predicted[filter_l] = tree_predict(X_l, tree['sl'])
        else:
            predicted[filter_l] = tree_predict(X_l, tree['sl'])
            predicted[~filter_l] = tree_predict(X_r, tree['sr'])

    return predicted

# %%
# Evaluación Arbol Manual usando MSE como criterio reducción de impureza
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

mse_tree_pred = tree_predict(X_test_enc, mse_tree)

mse_tree_rmse = np.sqrt(mean_squared_error(y_test, mse_tree_pred ))
mse_tree_mae = median_absolute_error(y_test, mse_tree_pred)

# Resultados
print("El RMSE del arbol manual usando mse como criterio para la reduccion de impureza es:", f"{mse_tree_rmse:.3f}")
print("El MAE del arbol manual usando mse como criterio para la reduccion de impureza es:", f"{mse_tree_mae:.3f}")
# Out:
# El RMSE del arbol manual usando mse como criterio para la reduccion de impureza es: 1692.100
# El MAE del arbol manual usando mse como criterio para la reduccion de impureza es: 955.601

# %%
# Evaluación Arbol Manual usando MAE como criterio reducción de impureza
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

mae_tree_pred = tree_predict(X_test_enc, mae_tree)

mae_tree_rmse = np.sqrt(mean_squared_error(y_test, mae_tree_pred ))
mae_tree_mae = median_absolute_error(y_test, mae_tree_pred)

# Resultados
print("El RMSE del arbol manual usando mae como criterio para la reduccion de impureza es:", f"{mae_tree_rmse:.3f}")
print("El MAE del arbol manual usando mae como criterio para la reduccion de impureza es:", f"{mae_tree_mae:.3f}")
# Out:
# El RMSE del arbol manual usando mae como criterio para la reduccion de impureza es: 1670.921
# El MAE del arbol manual usando mae como criterio para la reduccion de impureza es: 960.267

# %%
# Comparación gráfica de resultados
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))

# Predicciones Arbol MSE
plt.subplot(1, 2, 1)
plt.scatter(y_test, mse_tree_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.title("Arbol de Decisión Manual (MSE)")

# Predicciones Arbol MAE
plt.subplot(1, 2, 2)
plt.scatter(y_test, mae_tree_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.title("Arbol de Decisión Manual (MAE)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Punto 2 - Bagging manual
#
# En la celda 2 creen un modelo bagging **manualmente** con 10 árboles de regresión y comenten sobre el desempeño del modelo.

# %%
# Celda 2

# %% [markdown]
# ### Punto 3 - Bagging con librería
#
# En la celda 3, con la librería sklearn, entrenen un modelo bagging con 10 árboles de regresión y el parámetro `max_features` igual a `log(n_features)` y comenten sobre el desempeño del modelo.

# %%
# Celda 3

# %% [markdown]
# ### Punto 4 - Random forest con librería
#
# En la celda 4, usando la librería sklearn entrenen un modelo de Randon Forest para regresión  y comenten sobre el desempeño del modelo.

# %%
# Celda 4

# %% [markdown]
# ### Punto 5 - Calibración de parámetros Random forest
#
# En la celda 5, calibren los parámetros max_depth, max_features y n_estimators del modelo de Randon Forest para regresión, comenten sobre el desempeño del modelo y describan cómo cada parámetro afecta el desempeño del modelo.

# %%
# Celda 5

# %% [markdown]
# ### Punto 6 - XGBoost con librería
#
# En la celda 6 implementen un modelo XGBoost de regresión con la librería sklearn y comenten sobre el desempeño del modelo.

# %%
# Celda 6

# %% [markdown]
# ### Punto 7 - Calibración de parámetros XGBoost
#
# En la celda 7 calibren los parámetros learning rate, gamma y colsample_bytree del modelo XGBoost para regresión, comenten sobre el desempeño del modelo y describan cómo cada parámetro afecta el desempeño del modelo.

# %%
# Celda 7

# %% [markdown]
# ### Punto 8 - Comparación y análisis de resultados
# En la celda 8 comparen los resultados obtenidos de los diferentes modelos (random forest y XGBoost) y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 8
